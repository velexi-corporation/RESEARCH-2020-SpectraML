# %%
# environment set up
import keras
from keras.models import Sequential
from keras.layers import Reshape, Conv1D, MaxPooling1D, Flatten, Dense, Dropout
from keras.utils import to_categorical
import tensorflow as tf # only use tensorflow keras
import numpy as np
import matplotlib.pyplot as plt
import os
import random
import pandas as pd

# working folder
directory = "/Users/Srikar/Desktop/Velexi/spectra-ml/data"
os.chdir(directory)

# print(os.getcwd())
# Out:
# Using TensorFlow backend.
# /Users/Srikar/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.6 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.7
#   return f(*args, **kwds)

# %%
stddata_path = directory+"/Srikar-Standardized"
metadata = pd.read_csv(stddata_path+"/spectra-metadata.csv", sep="|")
metadata.head()
# Out:
#    spectrum_id   value_type                      material  \
# 0        23077  reflectance   Rangeland C03-022 S12% G22%
# 1        22344  reflectance  Marsh SPAL92%...a CRMS322v78
# 2        22136  reflectance       Tumbleweed ANP92-2C Dry
# 3        24017  reflectance   Rangeland L02-069 S00% G99%
# 4        21060  reflectance   Douglas-Fir YNP-DF-1 forest
#
#   spectrometer_purity_code measurement_type  \
# 0                   ASDFRa             AREF
# 1                   ASDFRa             AREF
# 2                    BECKa             AREF
# 3                   ASDFRa             AREF
# 4                  AVIRISb             RTGC
#
#                                        raw_data_path
# 0  ChapterV_Vegetation/splib07a_Rangeland_C03-022...
# 1  ChapterV_Vegetation/splib07a_Marsh_SPAL92%...a...
# 2  ChapterV_Vegetation/splib07a_Tumbleweed_ANP92-...
# 3  ChapterV_Vegetation/splib07a_Rangeland_L02-069...
# 4  ChapterV_Vegetation/splib07a_Douglas-Fir_YNP-D...

# %%
metadata.iloc[327, 1]
# Out:
# 'errorbar'

# %%
metadata.columns
# metadata[spectrometer_purity_code.str.find("NIC4")]
# Out:
# Index(['spectrum_id', 'value_type', 'material', 'spectrometer_purity_code',
#        'measurement_type', 'raw_data_path'],
#       dtype='object')

# %%
x = 0
for i in range(metadata.shape[0]):
    if metadata.iloc[i, 1] == 'reflectance':
        spectrum = pd.read_csv(stddata_path+"/{}.csv".format(metadata.iloc[i, 0]))
        for j in range(spectrum.shape[0]):
            if np.isnan(spectrum.iloc[j, 1]):
                print(str(metadata.iloc[i, 3]) + " " + str(metadata.iloc[i, 0]) + " " + str(metadata.iloc[i, 2]))
                x += 1
                break

print(x)
# Out:
# AVIRISb 21060 Douglas-Fir YNP-DF-1 forest
# AVIRISb 21098 Espruce-Sfir YNP-SF-5 forst
# AVIRISb 21594 Lodgepole-Pine YNP-LP1-A
# AVIRISb 21629 Lodgepole-Pine YNP-LP3-B
# ASDFRa 20883 Aspen Aspen-3 yellowGreenTop
# AVIRISb 22162 WhitebarkPine YNP-WB-2 frst
# AVIRISb 22072 Sagebrush YNP-SS-1
# AVIRISb 21085 Espruce-Sfir YNP-SF-2 forst
# AVIRISb 21081 Espruce-Sfir YNP-SF-1 forst
# ASDFRa 20892 Aspen Aspen-4 yellow-top
# AVIRISb 21614 Lodgepole-Pine YNP-LP2-A
# AVIRISb 21579 Lodgepole-Pine YNP-LP
# AVIRISb 22098 Sedge YNP-SE-1
# AVIRISb 21228 Grass-FescueWheatg YNP-FW-1
# AVIRISb 22150 Wetland YNP-WT-1
# AVIRISb 21046 Conifer-Meadow-Mix YNP-CM-1
# AVIRISb 22175 Willow YNP-WI-1
# AVIRISb 20915 Aspen YNP-AS-1 forest
# AVIRISb 22179 Willow-Sedge-Mix YNP-WS-1
# AVIRISb 21089 Espruce-Sfir YNP-SF-3 forst
# AVIRISb 21609 Lodgepole-Pine YNP-LP1-D
# AVIRISb 21064 Douglas-Fir YNP-DF-2 forest
# AVIRISb 21093 Espruce-Sfir YNP-SF-4 forst
# AVIRISb 22087 Sagebrush YNP-SS-4
# ASDFRa 21837 P.australis CRMS-0153 dryNPV
# AVIRISb 22154 Wetland YNP-WT-2
# ASDFRa 20985 Cactus Opuntia-1 purple_pad
# AVIRISb 22082 Sagebrush YNP-SS-3
# AVIRISb 21589 Lodgepole-Pine YNP-LP0-VIG
# AVIRISb 21604 Lodgepole-Pine YNP-LP1-C
# AVIRISb 21233 Grass-FescueWheatg YNP-FW-2
# ASDFRa 20874 Aspen Aspen-2 green-bottom
# AVIRISb 21242 Grass-Smoothbrome YNP-SB-1
# AVIRISb 21223 Grass-FescueNeedlg YNP-FN-1
# AVIRISb 22158 WhitebarkPine YNP-WB-1 frst
# AVIRISb 21068 Douglas-Fir YNP-DF-3 forest
# AVIRISb 21238 Grass-FescueWheatg YNP-FW-3
# AVIRISb 21599 Lodgepole-Pine YNP-LP1-B
# AVIRISb 21624 Lodgepole-Pine YNP-LP3-A
# AVIRISb 21584 Lodgepole-Pine YNP-LP0-MOD
# AVIRISb 22077 Sagebrush YNP-SS-2
# AVIRISb 20994 Cattail YNP-CT-1
# ASDFRa 20865 Aspen Aspen-1 green-top
# AVIRISb 21619 Lodgepole-Pine YNP-LP2-B
# NIC4b 11901 Buddingtnt+Na-Mont CU93-260B
# NIC4a 12364 Dickite+others CU91-219B
# NIC4aaa 13321 Talc+Clinochlore HS327.3B
# NIC4bb 13285 Sanidine+albite NMNH103200
# NIC4aau 13341 Teepleite+Trona NMNH102798
# NIC4b 12612 Kaol.5+MuscCU91-250A AMX13
# NIC4aa 12803 Magnesite+Hydromag HS47.3B
# NIC4b 13116 Pyrophyl.25+wxlKaol.75 AMX17
# NIC4bb 12743 Kaolin_Smect KLF508 .85Kaol
# NIC4a 12636 Kaol_Wxl+0.5Musc_Ruby AMX12
# NIC4bb 12435 Erionite+Offretite GDS72
# NIC4bbb 11869 Beidellite+Montmor GDS123
# NIC4a 12935 Muscovite+Chlorite CU91-253D
# NIC4aaa 12857 Microcline+others HS107.3B
# NIC4bb 13399 Zincite+Franklin HS147.3B
# NIC4bb 11831 Alunite_NH4+Jaro NMNH145596A
# NIC4b 11725 Alunite0.35K+.65Na CU91-217H
# NIC4bc 12240 ClinozoisiteEpidote HS299.2B
# NIC4a 11785 Alunite0.73K+.27Na CU91-217D
# BECKa 12073 Calcite.80wt+Kaol_CM9 GDS213
# NIC4bb 12415 Erionite+Merlinoite GDS144
# NIC4bbb 13054 Natrolite+Zeolite HS168.3B
# BECKa 12056 Calcite.80+Mont_Swy-1 GDS212
# NIC4cc 12676 Kaolin/Smect KLF511 .12Kaol
# NIC4b 12987 Muscovite-medlowAl CU91-250A
# NIC4aaa 12520 Halloysite+Kaolinite CM29
# NIC4bc 12836 Mesolite+Hydroxyapop GDS6
# NIC4bb 12723 Kaolin_Smect KLF506 .95kaol
# NIC4bb 12696 Kaolin_Smect H89-FR-2 .5Kao
# NIC4ccc 12291 Cordierite-QtzMus HS346.3B
# NIC4bbb 11751 Alunite0.5+Kaol_KGa-1 AMX3
# NIC4bbu 12901 Mordenite+Clinopt. GDS151
# NIC4b 11768 Alunite0.66K+.34Na CU91-217A
# NIC4bbb 12330 Covellite-Pyrite HS477.2B
# NIC4bb 12101 Chabazite+Thom+Wair HS193.3B
# BECKa 13510 H2O-Ice GDS136 77K
# NIC4cb 9306 Quartz GDS74 Sand Ottawa
# NIC4a 4725 Halloysite NMNH106237
# NIC4bb 9233 Pyroxmangite HS325.3B
# NIC4aa 6526 Lizardite NMNHR4687.b 165um
# NIC4aau 2004 Bloedite GDS147
# NIC4cbb 5329 Hypersthene PYX02.c 180um
# NIC4bcc 11564 Zoisite HS347.3B
# NIC4aaa 9541 Rivadavite NMNH170164
# NIC4bbb 240 Actinolite NMNHR16485
# NIC4bb 3199 Cookeite CAr-1.b 60-104um
# NIC4bc 7189 Montmorillonite CM20
# NIC4aaa 11406 Vesuvianite HS446.3B Idocr
# NIC4cdd 3778 Dumortierite HS190.3B
# NIC4bbb 4929 Hematite GDS69.d 30-45um
# NIC4bb 6293 Laumontite GDS5 Zeolite
# NIC4aa 5537 Illite IMt-1.b <2um
# NIC4bbb 8014 Olivine GDS70.a Fo89 165um
# NIC4aa 5723 Jarosite GDS98 K 90C Syn
# NIC4bbb 8065 Olivine GDS70.d Fo89 <60um
# NIC4bb 5508 Illite IMt-1.a
# NIC4bc 3265 Corrensite CorWa-1
# NIC4bb 10921 Topaz Little_3_Mine_#41
# NIC4bb 10950 Topaz Tarryalls_#4
# NIC4aa 1343 Anhydrite GDS42 <250um
# NIC4a 8879 Prochlorite SMR-14.b 32um
# NIC4bbb 1237 Andradite HS111.3B Garnet
# NIC4ccu 10530 Thenardite GDS146
# NIC4bbb 2982 Clinochlore NMNH83369
# NIC4b 3186 Cookeite CAr-1.b 60-104um
# NIC4aa 1387 Anorthite GDS28 Syn <74um
# NIC4bbb 1066 Amphibole NMNH78662
# ASDFRb 8927 Psilomelane HS139.1B
# NIC4bb 8449 Orthoclase NMNH142137 Fe
# NIC4bbb 8285 Olivine KI3188 Fo51 <60um
# NIC4bb 8175 Olivine HS285.4B Fo80
# NIC4bb 719 Alunite GDS83 Na63
# NIC4bb 11055 Topaz Wigwam_Area_#16
# NIC4a 9117 Pyrophyllite PYS1A <850um
# NIC4bbb 3817 Elbaite NMNH94217-1.b 196
# NIC4ccc 1170 Andesine HS142.3B
# NIC4ccc 4268 Glauconite HS313.3B
# NIC4ccu 3970 Epsomite GDS149
# NIC4cc 6170 Kieserite KIEDE1.a crse gr
# NIC4cb 7855 Nephrite HS296.3B
# NIC4aaa 2162 Butlerite GDS25
# NIC4bb 10354 Strontianite HS272.3B
# NIC4aaa 7449 Muscovite GDS111 Guatemala
# NIC4aa 7971 Nontronite SWa-1.b <2um
# NIC4aa 4044 Fluorapatite WS416
# NIC4bb 7293 Montmorillonite SCa-2.b
# NIC4bbb 293 Albite HS66.3B Plagioclase
# NIC4aa 11243 Ulexite HS441.3B
# NIC4aa 2735 Chlorite SMR-13.d 30-45um
# NIC4ccc 11136 Tremolite HS18.3B
# NIC4ccu 6970 Microcline HS82.3B Feldspr
# NIC4aau 8777 Polyhalite NMNH92669-4
# NIC4bb 10992 Topaz Wigwam_Area_3_#13
# NIC4bb 11013 Topaz Wigwam_Area_4_#14
# NIC4cbu 8142 Olivine GDS71.b Fo91 <60um
# NIC4ccc 4011 Fassaite HS118.3B
# NIC4cc 6432 Lepidolite NMNH105538
# NIC4bb 10769 Topaz Harris_Park_#17
# NIC4bb 6711 Malachite HS254.3B
# NIC4cc 1737 Augite WS592 Pyroxene
# NIC4a 740 Alunite GDS84 Na03
# NIC4bb 525 Almandine HS114.3B Garnet
# NIC4aa 8909 Prochlorite SMR-14.c <30um
# NIC4bbb 7954 Nontronite SWa-1.a
# NIC4cd 4412 Goethite WS220
# NIC4cbb 5312 Hypersthene PYX02.b 120um
# NIC4bb 1625 Antigorite NMNH96917.a >250
# NIC4bbu 9684 Sepiolite SepNev-1
# NIC4cbb 395 Albite HS324.3B Plagioclas
# NIC4cbb 6216 Knebelite HS419.3B
# NIC4bbb 4878 Hematite GDS69.a 150-250u
# NIC4bb 7233 Montmorillonite CM27
# NIC4cc 1198 Andradite GDS12 Garnet
# NIC4aa 3062 Clinochlore_Fe SC-CCa-1.b
# NIC4aa 7651 Muscovite GDS120 Pegma M.
# NIC4bc 2543 Chalcopyrite HS431.3B
# NIC4ddd 2892 Cinnabar HS133.3B
# NIC4aau 4432 Goethite WS222 Medium Gr.
# NIC4bb 5250 Hydroxyl-Apatite WS425
# NIC4cc 3216 Cookeite CAr-1.c <30um
# NIC4aa 5035 Heulandite GDS3
# NIC4bb 10748 Topaz Glen_Cove_#8
# NIC4aa 2349 Carnallite HS430.3B
# NIC4bbb 2466 Celestite HS251.3B Barite
# NIC4b 6093 Kaolinite KGa-2 (pxl)
# NIC4ccc 4319 Glaucophane HS426.3B
# NIC4bbb 10474 Talc HS21.3B
# NIC4bb 11076 Topaz Wigwam_Area_#10
# NIC4a 1037 Ammonio-Jarosite SCF-NHJ
# NIC4bb 10727 Topaz Glen_Cove_#6
# NIC4ccc 1446 Anorthite HS349.3B Plagio
# NIC4cc 10153 Sphene HS189.3B
# NIC4aa 5756 Jarosite GDS99 K 200C Syn
# NIC4bb 5135 Hornblende HS177.3B
# NIC4bbu 6501 Limonite HS41.3
# NIC4bb 11034 Topaz Wigwam_Area_5_#15
# NIC4b 7385 Muscovite CU93-1 low-Al Phyl
# NIC4bb 4100 Galena HS37.3
# NIC4bb 10971 Topaz Wigwam_Area_2_#12
# NIC4bc 685 Alunite GDS82 Na82
# NIC4cb 6737 Margarite GDS106
# NIC4bb 10264 Stilbite GDS8 Zeolite
# NIC4cc 6460 Lepidolite NMNH105543
# NIC4aaa 7495 Muscovite GDS113 Ruby
# NIC4ccc 3350 Cummingtonite HS294.3B
# NIC4cb 8129 Olivine GDS71.b Fo91 <60um
# NIC4bbu 7710 Muscovite HS24.3
# NIC4aaa 10433 Talc GDS23 74-250um
# NIC4cc 8664 Phlogopite WS496
# NIC4bb 2948 Clinochlore GDS159
# NIC4bb 7992 Oligoclase HS110.3B
# NIC4aa 3023 Clinochlore_Fe GDS157
# NIC4cc 6938 Microcline HS151.3B Feldsp
# NIC4cd 7915 Nontronite NG-1.a
# NIC4cc 11322 Uvarovite NMNH106661 Garnet
# NIC4bbb 8522 Pectolite NMNH94865.b
# NIC4aa 2718 Chlorite SMR-13.c 45-60um
# NIC4bc 2075 Brookite HS443.2B
# NIC4bbb 4679 Halloysite CM13
# NIC4aaa 9147 Pyrophyllite PYS1A fine gr
# NIC4aa 3079 Clinochlore_Fe SC-CCa-1.c
# NIC4bc 7211 Montmorillonite CM26
# NIC4dd 1492 Anthophyllite HS286.3B
# NIC4aaa 2290 Calcite WS272
# NIC4bc 10861 Topaz HS184.3B
# NIC4bbb 2662 Chlorite HS197.3B
# NIC4cbb 4477 Grossular NMNH155371 Garnet
# NIC4bc 9750 Sepiolite SepSp-1.AcB
# NIC4bbu 9637 Sauconite GDS135
# ASDFRb 8962 Psilomelane HS139.4B
# NIC4bbb 5272 Hypersthene NMNHC2368
# NIC4bb 1567 Antigorite NMNH96917.c 120
# NIC4bbu 7795 Natrolite NMNH83380 Zeolit
# NIC4cbb 8264 Olivine KI3054 Fo66 <60um
# NIC4bbu 9440 Rhodonite NMNHC6148 >250um
# NIC4cdb 8978 Pyrite GDS483.c 30-60um
# NIC4bbb 4946 Hematite GDS69.e 20-30um
# NIC4ccc 7161 Monticellite HS339.3B
# NIC4aaa 4738 Halloysite NMNH106237
# NIC4aa 753 Alunite GDS84 Na03
# NIC4aau 4645 Halite HS433.3B
# NIC4bbu 4177 Gaylussite NMNH102876-2
# NIC4bb 1533 Antigorite NMNH96917.e 32um
# NIC4bbu 2381 Carnallite NMNH98011
# NIC4bbu 8306 Olivine KI3189 Fo60 <60um
# NIC4bcb 2786 Chromite HS281.3B
# NIC4bbb 9617 Saponite SapCa-1.AcB
# NIC4bb 10900 Topaz Jos_#22
# NIC4cbb 8214 Olivine HS420.3B
# NIC4ccc 11096 Tourmaline HS282.2B
# NIC4bb 5958 Kaolinite CM7
# NIC4bb 1816 Barite HS79.3B
# BECKa 6792 Mascagnite GDS65.b (fr)
# NIC4aaa 9591 Sanidine GDS19 Feldspar
# NIC4cb 5168 Hornblende_Fe HS115.3B
# NIC4bb 8505 Pectolite NMNH94865.a
# NIC4bbb 211 Actinolite HS315.4B
# NIC4bbb 3736 Dolomite HS102.3B
# NIC4a 5710 Jarosite GDS98 K 90C Syn
# NIC4ccc 9206 Pyroxene HS119.3B
# NIC4cbc 9827 Serpentine HS8.3B
# NIC4cbb 1776 Axinite HS342.3B
# NIC4aa 6480 Lepidolite NMNH88526-1
# NIC4bbb 1867 Beidellite GDS124
# NIC4bb 7315 Montmorillonite STx-1
# NIC4aa 10381 Sulfur GDS94 Reagent
# NIC4bb 1017 Ammonio-Illite/Smect GDS87
# NIC4bcc 7349 Montmorillonite SWy-1
# NIC4bbb 8369 Olivine KI4143 Fo41 <60um
# NIC4bbb 260 Adularia GDS57 Orthoclase
# NIC4aa 11457 Witherite HS273.3B
# NIC4bbb 603 Almandine WS477 Garnet
# NIC4bb 9370 Rectorite RAr-1
# NIC4aa 9989 Sodium Bicarbonate GDS55
# NIC4aaa 8750 Pinnoite NMNH123943
# NIC4ccc 2234 Bytownite HS106.3B Plagio
# NIC4ccc 9479 Richterite HS336.3B Amphib
# NIC4cb 1131 Andalusite NMNHR17898 lggr
# NIC4cc 8999 Pyrite HS35.3
# NIC4aa 5914 Kaolinite CM3
# NIC4aa 10627 Thuringite SMR-15.c 32um
# NIC4aaa 7607 Muscovite GDS118 Capitan
# NIC4aaa 9130 Pyrophyllite PYS1A <850um
# NIC4bb 5188 Hornblende_Mg NMNH117329
# NIC4bb 7427 Muscovite GDS108
# NIC4aaa 7517 Muscovite GDS114 Marshall
# NIC4bbu 6359 Lepidocrocite GDS80 (Syn)
# NIC4bb 8949 Psilomelane HS139.3B
# NIC4cc 4498 Grossular WS483 Garnet
# NIC4bb 11164 Tremolite NMNH117611.HCL
# NIC4bb 8242 Olivine KI3005 Fo11 <60um
# NIC4cbu 5616 Jadeite HS343.3B
# NIC4bb 2926 Clinochlore GDS158 Flagstaff
# NIC4cb 9728 Sepiolite SepSp-1
# NIC4cbb 5414 Hypersthene PYX02.h >250um
# NIC4cc 8724 Pigeonite HS199.3B
# ASDFRb 8943 Psilomelane HS139.3B
# NIC4aa 8808 Prehnite GDS613.a <60um
# NIC4cb 4842 Hedenbergite NMNH119197
# NIC4b 2969 Clinochlore NMNH83369
# NIC4b 3531 Dickite NMNH106242
# NIC4bb 996 Alunite SUSTDA-20
# NIC4bbb 6106 Kaolinite KGa-2 (pxl)
# NIC4bb 5448 Illite GDS4 Marblehead
# NIC4dcc 3641 Diopside HS317.3B (Cr)Pyx
# NIC4a 960 Alunite RES10 NA56% Syn 450C
# NIC4a 5743 Jarosite GDS99 K 200C Syn
# NIC4dcc 4980 Hematite GDS69.g <10um
# NIC4cbb 10032 Spessartine NMNH14143 Garn
# NIC4aa 9890 Siderite HS271.3B
# NIC4cb 8112 Olivine GDS71.a Fo91 65um
# NIC4a 883 Alunite RES-2 K Syn (450C)
# NIC4ccu 9272 Pyrrhotite HS269.3B
# NIC4bb 10706 Topaz Crystal_Park_#2
# NIC4bcc 9957 Smaragdite HS290.3B Amphib
# NIC4ccc 3395 Cuprite HS127.3B
# NIC4bb 6025 Kaolinite GDS11 <63um
# NIC4aa 7881 Niter GDS43 (K-Saltpeter)
# NIC4bb 9513 Richterite NMNH150800 HCl
# NIC4aa 3045 Clinochlore_Fe SC-CCa-1.a
# NIC4ccc 3863 Enstatite NMNH128288
# NIC4aaa 7563 Muscovite GDS116 Tanzania
# NIC4a 8849 Prochlorite SMR-14.a 115um
# NIC4aa 9706 Sepiolite SepNev-1.AcB
# NIC4aa 8415 Opal TM8896 (Hyalite)
# NIC4ccc 6399 Lepidolite HS167.3B
# NIC4aau 5055 Heulandite NMNH84534
# NIC4ccc 4816 Hedenbergite HS10.3B
# NIC4bbb 8348 Olivine KI3377 Fo18 <60um
# NIC4bbb 4895 Hematite GDS69.b 104-150u
# NIC4bbu 6666 Magnetite HS78.3B
# NIC4cc 344 Albite HS143.3B Plagioclase
# NIC4cb 6560 Lizardite NMNHR4687.d <30um
# NIC4aa 5648 Jarosite GDS100 Na 90C Syn
# NIC4aa 7629 Muscovite GDS119 Mt Alamo
# NIC4aau 5892 Kainite NMNH83904
# NIC4b 944 Alunite RES-9 Summitv (400C)
# NIC4aau 1836 Bassanite GDS145 (syn)
# NIC4bc 463 Allanite HS293.3B
# NIC4cc 7032 Mizzonite BM1931-12 Scapol
# NIC4aa 6779 Mascagnite GDS65.a (coarse)
# NIC4cdu 1680 Arsenopyrite HS262.3B
# NIC4bcb 2827 Chrysocolla HS297.3B
# NIC4aau 10664 Tincalconite GDS142
# NIC4bb 1596 Antigorite NMNH96917.b 165
# NIC4aa 8892 Prochlorite SMR-14.b 32um
# NIC4bb 7369 Mordenite GDS18
# NIC4b 672 Alunite GDS82 Na82
# NIC4bb 5936 Kaolinite CM5
# NIC4bb 5230 Hydrogrossular NMNH120555
# NIC4cb 1118 Andalusite NMNHR17898 <74um
# NIC4bbb 8636 Phlogopite HS23.3B
# NIC4aaa 1962 Biotite HS28.3B
# NIC4bb 2750 Chlorite SMR-13.e <30um
# NIC4bb 4912 Hematite GDS69.c 60-104um
# NIC4aa 7010 Mirabilite GDS150 Na2SO4
# NIC4cc 9917 Siderophyllite NMNH104998
# NIC4aa 2697 Chlorite SMR-13.a 104-150um
# NIC4b 5992 Kaolinite CM9
# NIC4cc 10052 Spessartine WS480 Garnet
# NIC4bbu 6620 Magnetite HS195.3B
# NIC4cc 8561 Perthite HS415.3B
# NIC4bb 9412 Rhodochrosite HS338.3B
# NIC4bb 4541 Grossular WS485 Garnet
# NIC4ccc 6990 Microcline NMNH135231 FSpr
# NIC4a 802 Alunite GDS97 K Syn (150C)
# NIC4a 976 Alunite RES12 NA78% Syn 450C
# NIC4bcu 9062 Pyrolusite HS138.3B
# NIC4bbu 10303 Stilbite HS482.3B Zeolite
# NIC4bc 7822 Nepheline HS19.3
# NIC4bb 7932 Nontronite NG-1.b <2um fr
# NIC4bc 3950 Epidote HS328.3B
# NIC4bbb 3800 Elbaite NMNH94217-1.a 659
# NIC4bb 9391 Rhodochrosite HS67 <250um
# NIC4cb 5088 Hornblende HS16.3B
# NIC4bb 5864 Jarosite SJ-1 H3O 10-20%
# NIC4aa 2504 Chalcedony CU91-6A XRD
# NIC4ccc 11503 Wollastonite HS348.3B
# NIC4aaa 7585 Muscovite GDS117 Isingles
# NIC4bb 3169 Cookeite CAr-1.a 104-150um
# NIC4aau 10401 Syngenite GDS139
# NIC4cbu 6758 Marialite NMNH126018-2
# NIC4bbu 6899 Microcline HS108.3B Feldsp
# NIC4bb 560 Almandine WS475 Garnet
# NIC4bbu 3487 Diaspore HS416.3B
# NIC4bbb 582 Almandine WS476 Garnet
# NIC4bb 3311 Cronstedtite M3542
# NIC4bbb 2421 Cassiterite HS279.3B
# ASDFRb 8933 Psilomelane HS139.2B
# NIC4bbb 8090 Olivine GDS70.e Fo89 <30um
# NIC4bbb 1271 Andradite NMNH113829 Garnet
# NIC4bb 8327 Olivine KI3291 Fo29 <60um
# NIC4aaa 4592 Gypsum HS333.3B (Selenite)
# NIC4ccu 6332 Lazurite HS418.3B
# NIC4aa 6796 Mascagnite GDS65.b (fr)
# NIC4bb 5831 Jarosite NMNH95074-1 (Na)
# NIC4bbu 3990 Eugsterite GDS140 Syn
# NIC4bb 2597 Chlorapatite WS423
# NIC4bbb 3435 Datolite HS442.3B
# NIC4cbb 5397 Hypersthene PYX02.g 7um
# NIC4bc 10584 Thuringite SMR-15.a 115um
# NIC4bbb 646 Almandine WS479 Garnet
# NIC4bcb 4374 Goethite HS36.3B
# NIC4bbb 2201 Bytownite HS105.3B Plagio
# NIC4bbb 6005 Kaolinite CM9
# NIC4bb 423 Albite NMNHC5390 74-250um
# NIC4bbb 8031 Olivine GDS70.b Fo89 115um
# NIC4aa 6543 Lizardite NMNHR4687.c 70um
# NIC4bb 9662 Scolecite GDS7 Zeolite
# NIC4cc 10072 Spessartine WS481 Garnet
# NIC4aaa 1927 Beryl HS180.3B
# NIC4bbb 10510 Talc WS659
# NIC4bbb 3120 Clinoptilolite GDS2 Zeolite
# NIC4bbb 1887 Beryl GDS9 <150um gs
# NIC4bb 6059 Kaolinite KGa-1 (wxl)
# NIC4bb 4520 Grossular WS484 Garnet
# NIC4cbb 9570 Rutile HS126.3B
# NIC4cbb 5295 Hypersthene PYX02.a 12um
# NIC4cbb 3675 Diopside NMNHR18685 ~160
# NIC4cbb 625 Almandine WS478 Garnet
# NIC4a 915 Alunite RES-4 Na Syn (300C)
# NIC4aaa 1086 Analcime GDS1 Zeolite
# NIC4bbu 4353 Goethite GDS134
# NIC4a 899 Alunite RES-3 Na Syn (450C)
# NIC4cbb 5380 Hypersthene PYX02.f 60um
# NIC4bb 1550 Antigorite NMNH96917.d 70um
# NIC4b 5851 Jarosite SJ-1 H3O 20% Syn
# NIC4aa 5668 Jarosite GDS101 Na 200C Syn
# NIC4bbb 3904 Epidote GDS26.a 75-200um
# NIC4a 785 Alunite GDS96 K Syn (250C)
# NIC4a 3010 Clinochlore_Fe GDS157
# NIC4cb 8684 Phlogopite WS675
# NIC4aau 5208 Howlite GDS155
# NIC4bcu 5007 Hematite HS45.3
# NIC4bc 3237 Copiapite GDS21
# NIC4ccc 4455 Grossular HS113.3B-HCL
# NIC4bb 7267 Montmorillonite SAz-1
# NIC4bbb 3841 Endellite GDS16
# NIC4cbb 6267 Labradorite HS17.3B
# NIC4bb 10685 Topaz Cameron_Cone_#42
# NIC4aa 7405 Muscovite GDS107
# NIC4aa 10614 Thuringite SMR-15.b 80um
# NIC4bbb 5689 Jarosite GDS24 Na
# NIC4cc 6827 Meionite WS701
# NIC4bb 1365 Annite WS661 Biotite
# NIC4cc 6866 Microcline HS103.3B Feldsp
# NIC4cc 10010 Spessartine HS112.3B
# NIC4cbb 5363 Hypersthene PYX02.e 34um
# NIC4a 10601 Thuringite SMR-15.b 80um
# NIC4cbb 5346 Hypersthene PYX02.d 23um
# NIC4cc 11366 Vermiculite WS681
# NIC4bb 1300 Andradite WS487 Garnet
# NIC4aaa 7684 Muscovite HS146.3B
# NIC4aa 1407 Anorthite HS201.3B Plagio
# NIC4bbb 4963 Hematite GDS69.f 10-20um
# NIC4ccu 11288 Uralite HS345.3B
# NIC4ccc 2121 Brucite HS247.3B
# NIC4b 706 Alunite GDS83 Na63
# NIC4aa 8862 Prochlorite SMR-14.a 115um
# NIC4bbu 2632 Chlorite HS179.3B
# NIC4ccc 2043 Bronzite HS9.3B Pyroxene
# NIC4a 2684 Chlorite SMR-13.a 104-150um
# NIC4aau 11204 Ulexite GDS138
# NIC4bb 10798 Topaz Harris_Park_#9
# NIC4a 769 Alunite GDS95 Na Syn (150C)
# NIC4bbu 3148 Colemanite GDS143
# NIC4dbb 3590 Diopside HS15.3B Pyroxene
# NIC4bb 6581 Maghemite GDS81 Syn (M-3)
# NIC4cbb 1716 Augite WS588 Pyroxene
# NIC4buu 10094 Sphalerite HS136.3B
# NIC4bbb 8595 Phlogopite GDS20 fine fr
# NIC4aa 10644 Thuringite SMR-15.d <30um
# NIC4bcu 5571 Ilmenite HS231.3B
# NIC4bbb 164 Actinolite HS22.3B
# NIC4bbb 4216 Gibbsite HS423.3B
# NIC4aau 11184 Trona GDS148
# NIC4bb 4776 Hectorite SHCa-1.Ac-B
# NIC4bb 3544 Dickite NMNH106242
# NIC4bbb 7080 Monazite HS255.3B
# NIC4cd 10237 Staurolite HS188.3B
# NIC4bbb 8048 Olivine GDS70.c Fo89 70um
# NIC4bbb 7769 Natrolite HS169.3B Zeolite
# NIC4aa 8827 Prehnite GDS613.b >60um
# NIC4bbb 3099 Clinoptilolite GDS152 Zeol
# NIC4aaa 855 Alunite HS295.3B
# NIC4cc 1322 Andradite WS488 Garnet
# NIC4ccu 1984 Biotite WS660
# NIC4cc 10192 Spodumene HS210.3B
# NIC4aa 14705 Dihydrouracil SA-D7628 290K
# NIC4bb 16742 L-Tyrosine NF 85K
# NIC4aa 15723 Pentane SA-76878 fine fr86K
# NIC4aa 15078 Heptane SA-H2198 MedGrn 92K
# NIC4bb 14960 L-Glutamine NF
# NIC4aa 16447 Taurine NF
# NIC4aa 13878 5-Aminoorotic SA-191213 90K
# NIC4aa 14642 2-4-Diaminopyrimidine 90K
# NIC4aa 15631 Octane SA-74822 medfrost 87K
# NIC4aa 15246 Hypoxanthine SA-H9377 82K
# NIC4aa 15107 Hexane SA-139386 MedFrst87K
# NIC4aa 14402 6-Cyanopurine SA-852503
# NIC4bb 14973 L-Glutamine NF 85K
# NIC4aa 14306 Butane Camco frost 78K
# NIC4aa 15602 Nonane fine frost 84K
# NIC4aa 16847 Xanthine SA-X0626
# NIC4bb 14443 L-Cysteine SA-W326305
# NIC4aa 15205 5-Hydroxymethyluracil 90K
# NIC4aa 15386 L-Lysine SA-L5501 82K
# NIC4aa 14623 2-4-Diaminopyrimidine 468231
# NIC4aa 15367 L-Lysine SA-L5501
# NIC4aa 14778 Ethane MTG 77K
# NIC4aa 13941 5-Aminouracil SA-855286
# NIC4aa 15985 L-Proline SA-P0380
# NIC4aa 16580 Theobromine SA-T4500
# NIC4aa 16460 Taurine NF 85K
# NIC4aa 13766 DL-Alanine SA-A7502
# NIC4aa 15186 5-Hydroxymethyluracil
# NIC4aa 15227 Hypoxanthine SA-H9377
# NIC4aa 15409 Methane XCEL liquid T~77K
# NIC4bb 16729 L-Tyrosine NF
# BECKa 18960 Montmorill+Unleaded_Gas SWy
# BECKa 18945 Montmorill+TCE SWy saturated
# NIC4bb 19967 Praseodymium_Oxide GDS35
# NIC4a 18596 Cyanide_Cadmium_Potassium
# NIC4aa 20044 Samarium Oxide GDS36
# NIC4aa 19019 Neodymium_Oxide GDS34
# BECKa 18940 Montmorill+Benzene SWy 1ml
# NIC4aa 18965 Mylar_1-way_trans RefStd
# BECKa 18955 Montmorill+Trichlor SWy 1ml
# NIC4a 18639 Cyanide_Zinc_Potassium
# BECKa 18950 Montmorill+Toluene SWy .5ml
# NIC4a 18614 Cyanide_Nickel_Potassium
# 515

# %%
num_nic = 0
for i in range(metadata.shape[0]):
    if metadata.iloc[i, 3].find("NIC") != -1:
        num_nic += 1

print(num_nic)
# Out:
# 648
