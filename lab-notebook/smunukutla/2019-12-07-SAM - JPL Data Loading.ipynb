# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
data_dir = os.environ['DATA_DIR']
data_path = os.path.join(data_dir, "JPL_data")
os.chdir(data_path)

# %%
os.listdir()[1]
# Out:
# 'mineral.silicate.inosilicate.fine.tir.hypersth_1.jhu.nicolet.spectrum.txt'

# %%
fi = open(os.listdir()[1], "r")

data = pd.read_csv(os.path.join(data_path, "mineral.silicate.nesosilicate.coarse.vswir.ns-6a.jpl.beckman.spectrum.txt"), sep = "\s+", header=None, skipinitialspace=True, skiprows=21)
data.columns = {"Wavelength", "Reflectance"}
print(type(data))
data
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      Wavelength  Reflectance
# 0         0.400        49.52
# 1         0.401        49.49
# 2         0.402        49.52
# 3         0.403        49.56
# 4         0.404        49.55
# 5         0.405        49.64
# 6         0.406        49.55
# 7         0.407        49.58
# 8         0.408        49.76
# 9         0.409        49.73
# 10        0.410        49.62
# 11        0.411        49.67
# 12        0.412        49.79
# 13        0.413        49.67
# 14        0.414        49.68
# 15        0.415        49.67
# 16        0.416        49.76
# 17        0.417        49.82
# 18        0.418        49.73
# 19        0.419        49.64
# 20        0.420        49.64
# 21        0.421        49.82
# 22        0.422        49.79
# 23        0.423        49.70
# 24        0.424        49.61
# 25        0.425        49.76
# 26        0.426        49.75
# 27        0.427        49.69
# 28        0.428        49.69
# 29        0.429        49.75
# ..          ...          ...
# 796       2.384        38.58
# 797       2.388        38.28
# 798       2.392        37.93
# 799       2.396        37.59
# 800       2.400        37.16
# 801       2.404        36.68
# 802       2.408        36.21
# 803       2.412        35.83
# 804       2.416        35.37
# 805       2.420        35.04
# 806       2.424        34.75
# 807       2.428        34.48
# 808       2.432        34.12
# 809       2.436        33.66
# 810       2.440        33.20
# 811       2.444        32.66
# 812       2.448        32.07
# 813       2.452        31.36
# 814       2.456        30.47
# 815       2.460        29.64
# 816       2.464        28.79
# 817       2.468        27.88
# 818       2.472        26.94
# 819       2.476        25.98
# 820       2.480        25.12
# 821       2.484        24.17
# 822       2.488        23.18
# 823       2.492        22.26
# 824       2.496        21.30
# 825       2.500        20.46
#
# [826 rows x 2 columns]

# %%
# plt.plot(data["Reflectance"])
plt.plot(data.iloc[:, 1])
plt.title('Reflectance vs Wavelength')
plt.ylabel('Reflectance')
plt.xlabel('Wavelength')
# plt.legend(['Reflectance'], loc='upper right')
# Out:
# Text(0.5, 0, 'Wavelength')
