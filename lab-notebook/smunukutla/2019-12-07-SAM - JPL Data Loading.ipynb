# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
data_dir = os.environ['DATA_DIR']
data_path = os.path.join(data_dir, "JPL_data")
os.chdir(data_path)

# %%
metadata_path = os.path.join(data_path, "Manifest.txt")

# %%
# fi = open(os.listdir()[1], "r")

# data = pd.read_csv(metadata_path, sep = "\s+", header=None, skipinitialspace=True, skiprows=21)
metadata = pd.read_csv(metadata_path, header=None, index_col=False, sep = "\s+")
# data.columns = {"Wavelength", "Reflectance"}
metadata.columns = {"Spectrum"}
metadata = metadata[metadata.iloc[:, 0].str.contains("spectrum")]
metadata.reset_index(inplace=True, drop=True)
# print(type(metadata))
for i in range(metadata.shape[0]):
    print(metadata.iloc[i])
# Out:
# Spectrum    mineral.silicate.inosilicate.fine.tir.hypersth...
# Name: 0, dtype: object
# Spectrum    mineral.oxide.none.coarse.tir.ilmenite_1.jhu.n...
# Name: 1, dtype: object
# Spectrum    mineral.silicate.nesosilicate.coarse.tir.staur...
# Name: 2, dtype: object
# Spectrum    mineral.carbonate.none.medium.vswir.c-3a.jpl.b...
# Name: 3, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.tir.phlog...
# Name: 4, dtype: object
# Spectrum    mineral.silicate.inosilicate.medium.vswir.in-5...
# Name: 5, dtype: object
# Spectrum    mineral.silicate.inosilicate.coarse.tir.wollas...
# Name: 6, dtype: object
# Spectrum    mineral.phosphate.none.medium.vswir.p-4a.jpl.b...
# Name: 7, dtype: object
# Spectrum    mineral.carbonate.none.coarse.vswir.c-1a.jpl.b...
# Name: 8, dtype: object
# Spectrum    mineral.sulfate.none.coarse.vswir.so-1a.jpl.pe...
# Name: 9, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.tir.ps-21...
# Name: 10, dtype: object
# Spectrum    mineral.silicate.inosilicate.fine.tir.in-6a.jp...
# Name: 11, dtype: object
# Spectrum    mineral.element.none.fine.vswir.e-2a.jpl.perki...
# Name: 12, dtype: object
# Spectrum    mineral.silicate.inosilicate.coarse.vswir.in-5...
# Name: 13, dtype: object
# Spectrum    mineral.hydroxide.none.fine.vswir.oh-3a.jpl.be...
# Name: 14, dtype: object
# Spectrum    mineral.sulfate.none.fine.vswir.so-4a.jpl.perk...
# Name: 15, dtype: object
# Spectrum    mineral.sulfide.none.fine.vswir.s-4a.jpl.perki...
# Name: 16, dtype: object
# Spectrum    mineral.silicate.nesosilicate.fine.tir.olivine...
# Name: 17, dtype: object
# Spectrum    mineral.arsenate.none.medium.tir.a-2a.jpl.nico...
# Name: 18, dtype: object
# Spectrum    mineral.silicate.tectosilicate.fine.vswir.ts-1...
# Name: 19, dtype: object
# Spectrum    mineral.oxide.none.fine.vswir.o-12a.jpl.beckma...
# Name: 20, dtype: object
# Spectrum    mineral.carbonate.none.coarse.tir.c-4a.jpl.nic...
# Name: 21, dtype: object
# Spectrum    mineral.silicate.tectosilicate.medium.vswir.ts...
# Name: 22, dtype: object
# Spectrum    mineral.sulfide.none.medium.vswir.s-4a.jpl.per...
# Name: 23, dtype: object
# Spectrum    mineral.silicate.tectosilicate.coarse.tir.ts-5...
# Name: 24, dtype: object
# Spectrum    mineral.silicate.nesosilicate.medium.tir.ns-7a...
# Name: 25, dtype: object
# Spectrum    mineral.silicate.inosilicate.medium.tir.in-2a....
# Name: 26, dtype: object
# Spectrum    mineral.silicate.none.solid.tir.zoisite_1.jhu....
# Name: 27, dtype: object
# Spectrum    mineral.silicate.nesosilicate.coarse.vswir.ns-...
# Name: 28, dtype: object
# Spectrum    mineral.silicate.tectosilicate.coarse.vswir.ts...
# Name: 29, dtype: object
# Spectrum    mineral.silicate.inosilicate.solid.tir.wollast...
# Name: 30, dtype: object
# Spectrum    mineral.carbonate.none.coarse.vswir.c-11a.jpl....
# Name: 31, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.coarse.tir.ps-...
# Name: 32, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.tir.ps-2b...
# Name: 33, dtype: object
# Spectrum    mineral.hydroxide.none.solid.tir.goethite_2.jh...
# Name: 34, dtype: object
# Spectrum    mineral.silicate.inosilicate.coarse.tir.augite...
# Name: 35, dtype: object
# Spectrum    mineral.sulfate.none.medium.vswir.so-7a.jpl.be...
# Name: 36, dtype: object
# Spectrum    mineral.oxide.none.fine.vswir.o-3a.jpl.perkin....
# Name: 37, dtype: object
# Spectrum    mineral.sulfate.none.fine.tir.so-11a.jpl.nicol...
# Name: 38, dtype: object
# Spectrum    mineral.sulfide.none.coarse.vswir.s-3a.jpl.per...
# Name: 39, dtype: object
# Spectrum    mineral.silicate.tectosilicate.medium.tir.ts-6...
# Name: 40, dtype: object
# Spectrum    mineral.silicate.nesosilicate.coarse.tir.ns-4a...
# Name: 41, dtype: object
# Spectrum    mineral.silicate.inosilicate.coarse.tir.in-1a....
# Name: 42, dtype: object
# Spectrum    mineral.silicate.tectosilicate.coarse.vswir.ts...
# Name: 43, dtype: object
# Spectrum    mineral.silicate.inosilicate.medium.tir.in-9b....
# Name: 44, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.tir.illsm...
# Name: 45, dtype: object
# Spectrum    mineral.silicate.tectosilicate.coarse.vswir.ts...
# Name: 46, dtype: object
# Spectrum    mineral.silicate.nesosilicate.fine.tir.topaz_2...
# Name: 47, dtype: object
# Spectrum    mineral.sulfide.none.coarse.vswir.s-11a.jpl.be...
# Name: 48, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.tir.ps-9a...
# Name: 49, dtype: object
# Spectrum    mineral.silicate.tectosilicate.fine.tir.quartz...
# Name: 50, dtype: object
# Spectrum    mineral.sulfate.none.coarse.vswir.so-5a.jpl.pe...
# Name: 51, dtype: object
# Spectrum    mineral.carbonate.none.fine.vswir.c-5a.jpl.bec...
# Name: 52, dtype: object
# Spectrum    mineral.sulfate.none.fine.tir.anhydrite_1.jhu....
# Name: 53, dtype: object
# Spectrum    mineral.carbonate.none.medium.vswir.c-3e.jpl.b...
# Name: 54, dtype: object
# Spectrum    mineral.silicate.cyclosilicate.coarse.tir.tour...
# Name: 55, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.coarse.vswir.p...
# Name: 56, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.vswir.ps-...
# Name: 57, dtype: object
# Spectrum    mineral.silicate.nesosilicate.fine.vswir.ns-1a...
# Name: 58, dtype: object
# Spectrum    mineral.sulfate.none.coarse.tir.barite_1.jhu.n...
# Name: 59, dtype: object
# Spectrum    mineral.silicate.tectosilicate.fine.tir.nephel...
# Name: 60, dtype: object
# Spectrum    mineral.silicate.tectosilicate.solid.tir.leuci...
# Name: 61, dtype: object
# Spectrum    mineral.silicate.inosilicate.fine.tir.augite_1...
# Name: 62, dtype: object
# Spectrum    mineral.arsenate.none.coarse.tir.a-2a.jpl.nico...
# Name: 63, dtype: object
# Spectrum    mineral.carbonate.none.fine.vswir.c-5c.jpl.per...
# Name: 64, dtype: object
# Spectrum    mineral.carbonate.none.coarse.vswir.c-9a.jpl.b...
# Name: 65, dtype: object
# Spectrum    mineral.carbonate.none.medium.tir.c-4a.jpl.nic...
# Name: 66, dtype: object
# Spectrum    mineral.silicate.nesosilicate.coarse.vswir.ns-...
# Name: 67, dtype: object
# Spectrum    mineral.carbonate.none.medium.tir.c-10a.jpl.ni...
# Name: 68, dtype: object
# Spectrum    mineral.silicate.inosilicate.coarse.vswir.in-1...
# Name: 69, dtype: object
# Spectrum    mineral.silicate.inosilicate.solid.tir.diopsid...
# Name: 70, dtype: object
# Spectrum    mineral.sulfide.none.coarse.vswir.s-10a.jpl.pe...
# Name: 71, dtype: object
# Spectrum    mineral.oxide.none.coarse.tir.hematite_1.jhu.n...
# Name: 72, dtype: object
# Spectrum    mineral.sulfate.none.fine.vswir.so-6a.jpl.beck...
# Name: 73, dtype: object
# Spectrum    mineral.silicate.nesosilicate.coarse.tir.olivi...
# Name: 74, dtype: object
# Spectrum    mineral.silicate.tectosilicate.solid.tir.sodal...
# Name: 75, dtype: object
# Spectrum    mineral.sulfate.none.coarse.all.gypsumc.usgs.p...
# Name: 76, dtype: object
# Spectrum    mineral.silicate.tectosilicate.fine.vswir.ts-1...
# Name: 77, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.tir.ps-1a...
# Name: 78, dtype: object
# Spectrum    mineral.sulfate.none.coarse.tir.anhydrite_1.jh...
# Name: 79, dtype: object
# Spectrum    mineral.silicate.tectosilicate.medium.vswir.ts...
# Name: 80, dtype: object
# Spectrum    mineral.silicate.cyclosilicate.coarse.tir.cs-4...
# Name: 81, dtype: object
# Spectrum    mineral.silicate.cyclosilicate.coarse.vswir.cs...
# Name: 82, dtype: object
# Spectrum    mineral.silicate.tectosilicate.coarse.vswir.ts...
# Name: 83, dtype: object
# Spectrum    mineral.sulfate.none.fine.tir.so-7c.jpl.nicole...
# Name: 84, dtype: object
# Spectrum    mineral.borate.none.fine.tir.b-4a.jpl.nicolet....
# Name: 85, dtype: object
# Spectrum    mineral.sulfide.none.coarse.vswir.s-7a.jpl.per...
# Name: 86, dtype: object
# Spectrum    mineral.oxide.none.fine.vswir.o-7a.jpl.perkin....
# Name: 87, dtype: object
# Spectrum    mineral.silicate.tectosilicate.fine.tir.ts-4a....
# Name: 88, dtype: object
# Spectrum    mineral.sulfide.none.fine.tir.s-3a.jpl.nicolet...
# Name: 89, dtype: object
# Spectrum    mineral.silicate.inosilicate.coarse.tir.diopsi...
# Name: 90, dtype: object
# Spectrum    mineral.silicate.cyclosilicate.fine.tir.tourma...
# Name: 91, dtype: object
# Spectrum    mineral.silicate.tectosilicate.fine.vswir.ts-2...
# Name: 92, dtype: object
# Spectrum    mineral.silicate.nesosilicate.fine.tir.ns-7a.j...
# Name: 93, dtype: object
# Spectrum    mineral.silicate.nesosilicate.fine.tir.olivine...
# Name: 94, dtype: object
# Spectrum    mineral.sulfate.none.coarse.tir.so-2b.jpl.nico...
# Name: 95, dtype: object
# Spectrum    mineral.silicate.inosilicate.fine.vswir.in-6a....
# Name: 96, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.solid.tir.phlo...
# Name: 97, dtype: object
# Spectrum    mineral.silicate.inosilicate.coarse.vswir.in-9...
# Name: 98, dtype: object
# Spectrum    mineral.halide.none.fine.vswir.h-2b.jpl.beckma...
# Name: 99, dtype: object
# Spectrum    mineral.sulfide.none.fine.tir.pyroph_1.jhu.nic...
# Name: 100, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.vswir.ps-...
# Name: 101, dtype: object
# Spectrum    mineral.sulfide.none.medium.tir.s-4a.jpl.nicol...
# Name: 102, dtype: object
# Spectrum    mineral.silicate.nesosilicate.coarse.tir.olivi...
# Name: 103, dtype: object
# Spectrum    mineral.oxide.none.coarse.tir.o-15a.jpl.nicole...
# Name: 104, dtype: object
# Spectrum    mineral.silicate.inosilicate.coarse.tir.hornbl...
# Name: 105, dtype: object
# Spectrum    mineral.element.none.coarse.tir.e-2a.jpl.nicol...
# Name: 106, dtype: object
# Spectrum    mineral.carbonate.none.fine.vswir.c-3a.jpl.per...
# Name: 107, dtype: object
# Spectrum    mineral.silicate.sorosilicate.coarse.vswir.ss-...
# Name: 108, dtype: object
# Spectrum    mineral.silicate.cyclosilicate.coarse.vswir.cs...
# Name: 109, dtype: object
# Spectrum    mineral.sulfate.none.coarse.vswir.so-9a.jpl.pe...
# Name: 110, dtype: object
# Spectrum    mineral.carbonate.none.coarse.vswir.c-3e.jpl.p...
# Name: 111, dtype: object
# Spectrum    mineral.oxide.none.fine.tir.o-2a.jpl.nicolet.s...
# Name: 112, dtype: object
# Spectrum    mineral.silicate.tectosilicate.fine.vswir.ts-3...
# Name: 113, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.coarse.vswir.p...
# Name: 114, dtype: object
# Spectrum    mineral.silicate.inosilicate.coarse.vswir.in-2...
# Name: 115, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.tir.musco...
# Name: 116, dtype: object
# Spectrum    mineral.sulfide.none.fine.vswir.s-5a.jpl.beckm...
# Name: 117, dtype: object
# Spectrum    mineral.halide.none.medium.vswir.h-2a.jpl.perk...
# Name: 118, dtype: object
# Spectrum    mineral.borate.none.medium.tir.b-3a.jpl.nicole...
# Name: 119, dtype: object
# Spectrum    mineral.sulfate.none.coarse.tir.alunite_2.jhu....
# Name: 120, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.tir.montm...
# Name: 121, dtype: object
# Spectrum    mineral.silicate.tectosilicate.fine.tir.ts-1d....
# Name: 122, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.coarse.vswir.p...
# Name: 123, dtype: object
# Spectrum    mineral.silicate.tectosilicate.fine.tir.sanidi...
# Name: 124, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.tir.chrys...
# Name: 125, dtype: object
# Spectrum    mineral.oxide.none.coarse.vswir.o-8a.jpl.beckm...
# Name: 126, dtype: object
# Spectrum    mineral.silicate.inosilicate.fine.vswir.in-6a....
# Name: 127, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.coarse.vswir.p...
# Name: 128, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.vswir.ps-...
# Name: 129, dtype: object
# Spectrum    mineral.silicate.tectosilicate.medium.tir.ts-1...
# Name: 130, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.tir.bioti...
# Name: 131, dtype: object
# Spectrum    mineral.oxide.none.fine.vswir.o-8a.jpl.beckman...
# Name: 132, dtype: object
# Spectrum    mineral.oxide.none.coarse.tir.o-1a.jpl.nicolet...
# Name: 133, dtype: object
# Spectrum    mineral.carbonate.none.medium.vswir.c-12a.jpl....
# Name: 134, dtype: object
# Spectrum    mineral.carbonate.none.medium.vswir.c-3d.jpl.p...
# Name: 135, dtype: object
# Spectrum    mineral.sulfate.none.fine.tir.so-1a.jpl.nicole...
# Name: 136, dtype: object
# Spectrum    mineral.silicate.inosilicate.solid.tir.richter...
# Name: 137, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.vswir.ps-...
# Name: 138, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.tir.ps-12...
# Name: 139, dtype: object
# Spectrum    mineral.silicate.inosilicate.solid.tir.augite_...
# Name: 140, dtype: object
# Spectrum    mineral.borate.none.fine.vswir.b-2a.jpl.beckma...
# Name: 141, dtype: object
# Spectrum    mineral.silicate.inosilicate.solid.tir.hornble...
# Name: 142, dtype: object
# Spectrum    mineral.halide.none.fine.tir.h-3a.jpl.nicolet....
# Name: 143, dtype: object
# Spectrum    mineral.oxide.none.fine.tir.o-12a.jpl.nicolet....
# Name: 144, dtype: object
# Spectrum    mineral.silicate.tectosilicate.fine.vswir.ts-2...
# Name: 145, dtype: object
# Spectrum    mineral.silicate.inosilicate.fine.tir.hornblen...
# Name: 146, dtype: object
# Spectrum    mineral.phosphate.none.medium.vswir.p-2a.jpl.p...
# Name: 147, dtype: object
# Spectrum    mineral.silicate.tectosilicate.medium.vswir.ts...
# Name: 148, dtype: object
# Spectrum    mineral.halide.none.fine.vswir.h-1a.jpl.beckma...
# Name: 149, dtype: object
# Spectrum    mineral.borate.none.coarse.all.nmnh96075-3.usg...
# Name: 150, dtype: object
# Spectrum    mineral.halide.none.coarse.vswir.h-2a.jpl.beck...
# Name: 151, dtype: object
# Spectrum    mineral.silicate.tectosilicate.solid.tir.labra...
# Name: 152, dtype: object
# Spectrum    mineral.halide.none.coarse.vswir.h-1a.jpl.perk...
# Name: 153, dtype: object
# Spectrum    mineral.silicate.tectosilicate.medium.vswir.ts...
# Name: 154, dtype: object
# Spectrum    mineral.sulfide.none.coarse.tir.s-4a.jpl.nicol...
# Name: 155, dtype: object
# Spectrum    mineral.silicate.inosilicate.fine.vswir.in-2a....
# Name: 156, dtype: object
# Spectrum    mineral.sulfide.none.fine.vswir.s-8a.jpl.perki...
# Name: 157, dtype: object
# Spectrum    mineral.sulfate.none.coarse.vswir.so-7c.jpl.pe...
# Name: 158, dtype: object
# Spectrum    mineral.silicate.sorosilicate.coarse.tir.ss-1a...
# Name: 159, dtype: object
# Spectrum    mineral.chloride.none.coarse.all.nmnh98011.usg...
# Name: 160, dtype: object
# Spectrum    mineral.sulfate.none.fine.vswir.so-8a.jpl.perk...
# Name: 161, dtype: object
# Spectrum    mineral.element.none.fine.tir.e-2a.jpl.nicolet...
# Name: 162, dtype: object
# Spectrum    mineral.silicate.nesosilicate.fine.tir.olivine...
# Name: 163, dtype: object
# Spectrum    mineral.silicate.nesosilicate.fine.vswir.ns-9a...
# Name: 164, dtype: object
# Spectrum    mineral.sulfate.none.coarse.tir.so-1a.jpl.nico...
# Name: 165, dtype: object
# Spectrum    mineral.silicate.tectosilicate.fine.vswir.ts-1...
# Name: 166, dtype: object
# Spectrum    mineral.carbonate.none.solid.tir.aragonite_1.j...
# Name: 167, dtype: object
# Spectrum    mineral.carbonate.none.medium.vswir.c-5c.jpl.b...
# Name: 168, dtype: object
# Spectrum    mineral.carbonate.none.solid.tir.dolomite_3.jh...
# Name: 169, dtype: object
# Spectrum    mineral.element.none.medium.tir.e-2a.jpl.nicol...
# Name: 170, dtype: object
# Spectrum    mineral.silicate.sorosilicate.coarse.vswir.ss-...
# Name: 171, dtype: object
# Spectrum    mineral.silicate.sorosilicate.medium.tir.ss-2a...
# Name: 172, dtype: object
# Spectrum    mineral.oxide.none.fine.tir.o-1b.jpl.nicolet.s...
# Name: 173, dtype: object
# Spectrum    mineral.carbonate.none.fine.vswir.c-7a.jpl.per...
# Name: 174, dtype: object
# Spectrum    mineral.silicate.cyclosilicate.fine.vswir.cs-3...
# Name: 175, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.vswir.ps-...
# Name: 176, dtype: object
# Spectrum    mineral.sulfate.none.coarse.all.gds147.usgs.pe...
# Name: 177, dtype: object
# Spectrum    mineral.silicate.nesosilicate.medium.vswir.ns-...
# Name: 178, dtype: object
# Spectrum    mineral.borate.none.coarse.all.ulexite.usgs.pe...
# Name: 179, dtype: object
# Spectrum    mineral.oxide.none.coarse.tir.magnet_1.jhu.nic...
# Name: 180, dtype: object
# Spectrum    mineral.oxide.none.medium.tir.o-1a.jpl.nicolet...
# Name: 181, dtype: object
# Spectrum    mineral.silicate.tectosilicate.medium.vswir.ts...
# Name: 182, dtype: object
# Spectrum    mineral.silicate.sorosilicate.fine.tir.ss-3a.j...
# Name: 183, dtype: object
# Spectrum    mineral.phosphate.none.coarse.vswir.p-1a.jpl.p...
# Name: 184, dtype: object
# Spectrum    mineral.sulfate.none.fine.tir.so-2b.jpl.nicole...
# Name: 185, dtype: object
# Spectrum    mineral.borate.none.coarse.tir.b-3a.jpl.nicole...
# Name: 186, dtype: object
# Spectrum    mineral.sulfide.none.coarse.vswir.s-4a.jpl.bec...
# Name: 187, dtype: object
# Spectrum    mineral.tungstate.none.fine.vswir.t-1a.jpl.per...
# Name: 188, dtype: object
# Spectrum    mineral.sulfide.none.medium.vswir.s-6a.jpl.bec...
# Name: 189, dtype: object
# Spectrum    mineral.sulfide.none.medium.vswir.s-8a.jpl.per...
# Name: 190, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.medium.tir.ps-...
# Name: 191, dtype: object
# Spectrum    mineral.silicate.nesosilicate.medium.vswir.ns-...
# Name: 192, dtype: object
# Spectrum    mineral.silicate.nesosilicate.coarse.vswir.ns-...
# Name: 193, dtype: object
# Spectrum    mineral.silicate.inosilicate.coarse.vswir.in-1...
# Name: 194, dtype: object
# Spectrum    mineral.silicate.tectosilicate.fine.vswir.ts-1...
# Name: 195, dtype: object
# Spectrum    mineral.sulfide.none.fine.vswir.s-12a.jpl.beck...
# Name: 196, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.coarse.tir.ps-...
# Name: 197, dtype: object
# Spectrum    mineral.oxide.none.medium.vswir.o-2a.jpl.beckm...
# Name: 198, dtype: object
# Spectrum    mineral.sulfate.none.fine.tir.so-9a.jpl.nicole...
# Name: 199, dtype: object
# Spectrum    mineral.sulfate.none.coarse.vswir.so-8a.jpl.be...
# Name: 200, dtype: object
# Spectrum    mineral.borate.none.medium.vswir.b-6a.jpl.beck...
# Name: 201, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.tir.ps-12...
# Name: 202, dtype: object
# Spectrum    mineral.borate.none.coarse.vswir.b-4a.jpl.beck...
# Name: 203, dtype: object
# Spectrum    mineral.carbonate.none.fine.tir.c-4a.jpl.nicol...
# Name: 204, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.medium.tir.ps-...
# Name: 205, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.coarse.tir.ps-...
# Name: 206, dtype: object
# Spectrum    mineral.silicate.inosilicate.solid.tir.enstati...
# Name: 207, dtype: object
# Spectrum    mineral.borate.none.coarse.all.nmnh170164.usgs...
# Name: 208, dtype: object
# Spectrum    mineral.silicate.nesosilicate.coarse.tir.topaz...
# Name: 209, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.coarse.vswir.p...
# Name: 210, dtype: object
# Spectrum    mineral.oxide.none.coarse.vswir.o-7a.jpl.beckm...
# Name: 211, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.vswir.ps-...
# Name: 212, dtype: object
# Spectrum    mineral.oxide.none.fine.vswir.o-7a.jpl.beckman...
# Name: 213, dtype: object
# Spectrum    mineral.silicate.cyclosilicate.solid.tir.beryl...
# Name: 214, dtype: object
# Spectrum    mineral.borate.none.coarse.vswir.b-3a.jpl.beck...
# Name: 215, dtype: object
# Spectrum    mineral.carbonate.none.fine.tir.c-3a.jpl.nicol...
# Name: 216, dtype: object
# Spectrum    mineral.phosphate.none.fine.vswir.p-3a.jpl.per...
# Name: 217, dtype: object
# Spectrum    mineral.silicate.tectosilicate.coarse.vswir.ts...
# Name: 218, dtype: object
# Spectrum    mineral.carbonate.none.coarse.vswir.c-5c.jpl.p...
# Name: 219, dtype: object
# Spectrum    mineral.borate.none.medium.vswir.b-1a.jpl.beck...
# Name: 220, dtype: object
# Spectrum    mineral.element.none.coarse.vswir.e-2a.jpl.per...
# Name: 221, dtype: object
# Spectrum    mineral.sulfate.none.medium.tir.so-11a.jpl.nic...
# Name: 222, dtype: object
# Spectrum    mineral.carbonate.none.medium.vswir.c-8a.jpl.p...
# Name: 223, dtype: object
# Spectrum    mineral.silicate.cyclosilicate.medium.vswir.cs...
# Name: 224, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.coarse.tir.ps-...
# Name: 225, dtype: object
# Spectrum    mineral.oxide.none.medium.tir.o-6a.jpl.nicolet...
# Name: 226, dtype: object
# Spectrum    mineral.silicate.tectosilicate.medium.vswir.ts...
# Name: 227, dtype: object
# Spectrum    mineral.silicate.inosilicate.solid.tir.bustami...
# Name: 228, dtype: object
# Spectrum    mineral.silicate.cyclosilicate.fine.vswir.cs-4...
# Name: 229, dtype: object
# Spectrum    mineral.sulfide.none.medium.vswir.s-1a.jpl.bec...
# Name: 230, dtype: object
# Spectrum    mineral.silicate.inosilicate.fine.tir.in-12a.j...
# Name: 231, dtype: object
# Spectrum    mineral.sulfide.none.coarse.vswir.s-3a.jpl.bec...
# Name: 232, dtype: object
# Spectrum    mineral.silicate.nesosilicate.solid.tir.olivin...
# Name: 233, dtype: object
# Spectrum    mineral.silicate.inosilicate.solid.tir.tremol_...
# Name: 234, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.vswir.ps-...
# Name: 235, dtype: object
# Spectrum    mineral.borate.none.coarse.tir.b-4a.jpl.nicole...
# Name: 236, dtype: object
# Spectrum    mineral.silicate.sorosilicate.fine.vswir.ss-1a...
# Name: 237, dtype: object
# Spectrum    mineral.sulfate.none.medium.vswir.so-4a.jpl.pe...
# Name: 238, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.tir.illit...
# Name: 239, dtype: object
# Spectrum    mineral.carbonate.none.coarse.vswir.c-3d.jpl.b...
# Name: 240, dtype: object
# Spectrum    mineral.phosphate.none.coarse.tir.p-1a.jpl.nic...
# Name: 241, dtype: object
# Spectrum    mineral.borate.none.coarse.vswir.b-2a.jpl.perk...
# Name: 242, dtype: object
# Spectrum    mineral.borate.none.fine.vswir.b-6a.jpl.perkin...
# Name: 243, dtype: object
# Spectrum    mineral.sulfate.none.coarse.tir.gypsum_2.jhu.n...
# Name: 244, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.coarse.vswir.p...
# Name: 245, dtype: object
# Spectrum    mineral.silicate.inosilicate.coarse.vswir.in-1...
# Name: 246, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.medium.vswir.p...
# Name: 247, dtype: object
# Spectrum    mineral.sulfate.none.medium.tir.so-5a.jpl.nico...
# Name: 248, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.tir.prehn...
# Name: 249, dtype: object
# Spectrum    mineral.sulfate.none.fine.tir.alunite_1.jhu.ni...
# Name: 250, dtype: object
# Spectrum    mineral.silicate.sorosilicate.coarse.tir.vesuv...
# Name: 251, dtype: object
# Spectrum    mineral.oxide.none.medium.vswir.o-8a.jpl.perki...
# Name: 252, dtype: object
# Spectrum    mineral.arsenate.none.fine.vswir.a-2a.jpl.perk...
# Name: 253, dtype: object
# Spectrum    mineral.silicate.tectosilicate.medium.vswir.ts...
# Name: 254, dtype: object
# Spectrum    mineral.sulfide.none.coarse.tir.s-3a.jpl.nicol...
# Name: 255, dtype: object
# Spectrum    mineral.borate.none.medium.vswir.b-5a.jpl.perk...
# Name: 256, dtype: object
# Spectrum    mineral.carbonate.none.coarse.tir.c-5c.jpl.nic...
# Name: 257, dtype: object
# Spectrum    mineral.silicate.nesosilicate.medium.vswir.ns-...
# Name: 258, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.coarse.tir.ps-...
# Name: 259, dtype: object
# Spectrum    mineral.sulfate.none.coarse.tir.so-6a.jpl.nico...
# Name: 260, dtype: object
# Spectrum    mineral.sulfide.none.medium.vswir.s-11a.jpl.pe...
# Name: 261, dtype: object
# Spectrum    mineral.arsenate.none.medium.vswir.a-2a.jpl.pe...
# Name: 262, dtype: object
# Spectrum    mineral.halide.none.fine.tir.h-4a.jpl.nicolet....
# Name: 263, dtype: object
# Spectrum    mineral.carbonate.none.coarse.tir.cerussite_1....
# Name: 264, dtype: object
# Spectrum    mineral.sulfide.none.medium.vswir.s-9a.jpl.bec...
# Name: 265, dtype: object
# Spectrum    mineral.silicate.nesosilicate.coarse.tir.olivi...
# Name: 266, dtype: object
# Spectrum    mineral.borate.none.fine.vswir.b-5a.jpl.beckma...
# Name: 267, dtype: object
# Spectrum    mineral.carbonate.none.fine.tir.c-3e.jpl.nicol...
# Name: 268, dtype: object
# Spectrum    mineral.silicate.cyclosilicate.fine.tir.beryl_...
# Name: 269, dtype: object
# Spectrum    mineral.silicate.tectosilicate.medium.vswir.ts...
# Name: 270, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.medium.vswir.p...
# Name: 271, dtype: object
# Spectrum    mineral.silicate.tectosilicate.fine.vswir.ts-5...
# Name: 272, dtype: object
# Spectrum    mineral.oxide.none.fine.tir.o-15a.jpl.nicolet....
# Name: 273, dtype: object
# Spectrum    mineral.tungstate.none.coarse.vswir.t-1a.jpl.p...
# Name: 274, dtype: object
# Spectrum    mineral.silicate.nesosilicate.medium.vswir.ns-...
# Name: 275, dtype: object
# Spectrum    mineral.silicate.inosilicate.medium.vswir.in-9...
# Name: 276, dtype: object
# Spectrum    mineral.carbonate.none.medium.vswir.c-10a.jpl....
# Name: 277, dtype: object
# Spectrum    mineral.silicate.nesosilicate.coarse.tir.pyrop...
# Name: 278, dtype: object
# Spectrum    mineral.oxide.none.fine.tir.magnet_1.jhu.nicol...
# Name: 279, dtype: object
# Spectrum    mineral.silicate.nesosilicate.coarse.tir.andal...
# Name: 280, dtype: object
# Spectrum    mineral.sulfate.none.coarse.vswir.so-7a.jpl.be...
# Name: 281, dtype: object
# Spectrum    mineral.borate.none.medium.tir.b-4a.jpl.nicole...
# Name: 282, dtype: object
# Spectrum    mineral.element.none.medium.vswir.e-1a.jpl.per...
# Name: 283, dtype: object
# Spectrum    mineral.silicate.tectosilicate.medium.vswir.ts...
# Name: 284, dtype: object
# Spectrum    mineral.silicate.tectosilicate.coarse.tir.ts-1...
# Name: 285, dtype: object
# Spectrum    mineral.sulfide.none.medium.vswir.s-11a.jpl.be...
# Name: 286, dtype: object
# Spectrum    mineral.sulfate.none.fine.tir.so-6a.jpl.nicole...
# Name: 287, dtype: object
# Spectrum    mineral.oxide.none.coarse.tir.o-6a.jpl.nicolet...
# Name: 288, dtype: object
# Spectrum    mineral.silicate.tectosilicate.medium.tir.ts-1...
# Name: 289, dtype: object
# Spectrum    mineral.silicate.tectosilicate.medium.vswir.ts...
# Name: 290, dtype: object
# Spectrum    mineral.silicate.nesosilicate.fine.vswir.ns-4a...
# Name: 291, dtype: object
# Spectrum    mineral.silicate.inosilicate.fine.vswir.in-1a....
# Name: 292, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.medium.tir.ps-...
# Name: 293, dtype: object
# Spectrum    mineral.arsenate.none.coarse.vswir.a-1a.jpl.pe...
# Name: 294, dtype: object
# Spectrum    mineral.silicate.inosilicate.fine.tir.acmite_2...
# Name: 295, dtype: object
# Spectrum    mineral.oxide.none.medium.tir.o-11a.jpl.nicole...
# Name: 296, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.coarse.tir.kao...
# Name: 297, dtype: object
# Spectrum    mineral.borate.none.fine.vswir.b-2a.jpl.perkin...
# Name: 298, dtype: object
# Spectrum    mineral.borate.none.coarse.vswir.b-6a.jpl.perk...
# Name: 299, dtype: object
# Spectrum    mineral.halide.none.fine.vswir.h-1a.jpl.perkin...
# Name: 300, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.coarse.vswir.p...
# Name: 301, dtype: object
# Spectrum    mineral.sulfide.none.fine.vswir.s-2a.jpl.beckm...
# Name: 302, dtype: object
# Spectrum    mineral.silicate.inosilicate.solid.tir.pectol_...
# Name: 303, dtype: object
# Spectrum    mineral.silicate.inosilicate.coarse.vswir.in-1...
# Name: 304, dtype: object
# Spectrum    mineral.phosphate.none.medium.tir.p-1a.jpl.nic...
# Name: 305, dtype: object
# Spectrum    mineral.silicate.inosilicate.coarse.vswir.in-5...
# Name: 306, dtype: object
# Spectrum    mineral.sulfate.none.fine.vswir.so-7c.jpl.beck...
# Name: 307, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.vswir.ps-...
# Name: 308, dtype: object
# Spectrum    mineral.silicate.inosilicate.medium.vswir.in-4...
# Name: 309, dtype: object
# Spectrum    mineral.sulfide.none.medium.tir.s-3a.jpl.nicol...
# Name: 310, dtype: object
# Spectrum    mineral.silicate.nesosilicate.fine.tir.datolit...
# Name: 311, dtype: object
# Spectrum    mineral.carbonate.none.medium.tir.c-5c.jpl.nic...
# Name: 312, dtype: object
# Spectrum    mineral.borate.none.medium.vswir.b-1a.jpl.perk...
# Name: 313, dtype: object
# Spectrum    mineral.oxide.none.solid.tir.magnet_1.jhu.nico...
# Name: 314, dtype: object
# Spectrum    mineral.silicate.nesosilicate.solid.tir.pyrope...
# Name: 315, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.coarse.vswir.p...
# Name: 316, dtype: object
# Spectrum    mineral.silicate.tectosilicate.medium.vswir.ts...
# Name: 317, dtype: object
# Spectrum    mineral.silicate.tectosilicate.medium.tir.ts-1...
# Name: 318, dtype: object
# Spectrum    mineral.silicate.tectosilicate.coarse.vswir.ts...
# Name: 319, dtype: object
# Spectrum    mineral.sulfide.none.medium.tir.s-11a.jpl.nico...
# Name: 320, dtype: object
# Spectrum    mineral.silicate.nesosilicate.fine.tir.olivine...
# Name: 321, dtype: object
# Spectrum    mineral.silicate.inosilicate.solid.tir.acmite_...
# Name: 322, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.vswir.ps-...
# Name: 323, dtype: object
# Spectrum    mineral.carbonate.none.coarse.vswir.c-7a.jpl.p...
# Name: 324, dtype: object
# Spectrum    mineral.silicate.tectosilicate.medium.tir.ts-2...
# Name: 325, dtype: object
# Spectrum    mineral.silicate.cyclosilicate.coarse.tir.cs-3...
# Name: 326, dtype: object
# Spectrum    mineral.silicate.nesosilicate.coarse.vswir.ns-...
# Name: 327, dtype: object
# Spectrum    mineral.silicate.cyclosilicate.fine.vswir.cs-3...
# Name: 328, dtype: object
# Spectrum    mineral.sulfate.none.fine.vswir.so-11a.jpl.per...
# Name: 329, dtype: object
# Spectrum    mineral.silicate.inosilicate.fine.tir.pectol_2...
# Name: 330, dtype: object
# Spectrum    mineral.sulfate.none.coarse.vswir.so-10a.jpl.b...
# Name: 331, dtype: object
# Spectrum    mineral.sulfide.none.fine.tir.s-4a.jpl.nicolet...
# Name: 332, dtype: object
# Spectrum    mineral.silicate.tectosilicate.fine.tir.ts-3a....
# Name: 333, dtype: object
# Spectrum    mineral.silicate.inosilicate.medium.tir.in-10b...
# Name: 334, dtype: object
# Spectrum    mineral.borate.none.fine.tir.b-3a.jpl.nicolet....
# Name: 335, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.tir.ps-6a...
# Name: 336, dtype: object
# Spectrum    mineral.silicate.tectosilicate.coarse.tir.chab...
# Name: 337, dtype: object
# Spectrum    mineral.silicate.tectosilicate.fine.vswir.ts-1...
# Name: 338, dtype: object
# Spectrum    mineral.silicate.tectosilicate.medium.tir.ts-9...
# Name: 339, dtype: object
# Spectrum    mineral.silicate.nesosilicate.medium.tir.ns-3b...
# Name: 340, dtype: object
# Spectrum    mineral.silicate.inosilicate.fine.vswir.in-10b...
# Name: 341, dtype: object
# Spectrum    mineral.silicate.tectosilicate.coarse.tir.ts-1...
# Name: 342, dtype: object
# Spectrum    mineral.silicate.nesosilicate.coarse.vswir.ns-...
# Name: 343, dtype: object
# Spectrum    mineral.silicate.inosilicate.medium.vswir.in-1...
# Name: 344, dtype: object
# Spectrum    mineral.carbonate.none.coarse.tir.dolomite_3.j...
# Name: 345, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.coarse.vswir.p...
# Name: 346, dtype: object
# Spectrum    mineral.sulfate.none.medium.vswir.so-8a.jpl.be...
# Name: 347, dtype: object
# Spectrum    mineral.silicate.inosilicate.coarse.tir.tremol...
# Name: 348, dtype: object
# Spectrum    mineral.carbonate.none.medium.tir.c-3a.jpl.nic...
# Name: 349, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.vswir.ps-...
# Name: 350, dtype: object
# Spectrum    mineral.silicate.inosilicate.medium.vswir.in-8...
# Name: 351, dtype: object
# Spectrum    mineral.carbonate.none.coarse.tir.c-3e.jpl.nic...
# Name: 352, dtype: object
# Spectrum    mineral.silicate.tectosilicate.coarse.vswir.ts...
# Name: 353, dtype: object
# Spectrum    mineral.sulfate.none.fine.vswir.so-1a.jpl.beck...
# Name: 354, dtype: object
# Spectrum    mineral.tungstate.none.coarse.vswir.t-1a.jpl.b...
# Name: 355, dtype: object
# Spectrum    mineral.silicate.sorosilicate.fine.vswir.ss-1a...
# Name: 356, dtype: object
# Spectrum    mineral.oxide.none.fine.tir.hematite_1.jhu.nic...
# Name: 357, dtype: object
# Spectrum    mineral.carbonate.none.fine.vswir.c-2a.jpl.bec...
# Name: 358, dtype: object
# Spectrum    mineral.sulfide.none.fine.tir.s-11a.jpl.nicole...
# Name: 359, dtype: object
# Spectrum    mineral.oxide.none.coarse.vswir.o-7a.jpl.perki...
# Name: 360, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.medium.tir.ps-...
# Name: 361, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.medium.vswir.p...
# Name: 362, dtype: object
# Spectrum    mineral.silicate.sorosilicate.medium.vswir.ss-...
# Name: 363, dtype: object
# Spectrum    mineral.silicate.inosilicate.fine.tir.richter_...
# Name: 364, dtype: object
# Spectrum    mineral.silicate.tectosilicate.solid.tir.morde...
# Name: 365, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.coarse.tir.ps-...
# Name: 366, dtype: object
# Spectrum    mineral.silicate.inosilicate.coarse.tir.richte...
# Name: 367, dtype: object
# Spectrum    mineral.silicate.tectosilicate.coarse.tir.quar...
# Name: 368, dtype: object
# Spectrum    mineral.silicate.nesosilicate.fine.tir.ns-3b.j...
# Name: 369, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.medium.vswir.p...
# Name: 370, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.coarse.tir.mon...
# Name: 371, dtype: object
# Spectrum    mineral.silicate.inosilicate.medium.tir.in-13a...
# Name: 372, dtype: object
# Spectrum    mineral.carbonate.none.coarse.vswir.c-12a.jpl....
# Name: 373, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.vswir.ps-...
# Name: 374, dtype: object
# Spectrum    mineral.carbonate.none.coarse.vswir.c-3a.jpl.p...
# Name: 375, dtype: object
# Spectrum    mineral.carbonate.none.fine.vswir.c-3e.jpl.per...
# Name: 376, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.medium.vswir.p...
# Name: 377, dtype: object
# Spectrum    mineral.silicate.inosilicate.coarse.tir.in-6a....
# Name: 378, dtype: object
# Spectrum    mineral.silicate.tectosilicate.medium.tir.ts-1...
# Name: 379, dtype: object
# Spectrum    mineral.carbonate.none.fine.tir.c-5c.jpl.nicol...
# Name: 380, dtype: object
# Spectrum    mineral.element.none.medium.vswir.e-1a.jpl.bec...
# Name: 381, dtype: object
# Spectrum    mineral.silicate.tectosilicate.coarse.tir.neph...
# Name: 382, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.coarse.vswir.p...
# Name: 383, dtype: object
# Spectrum    mineral.silicate.nesosilicate.solid.tir.andrad...
# Name: 384, dtype: object
# Spectrum    mineral.silicate.tectosilicate.coarse.vswir.ts...
# Name: 385, dtype: object
# Spectrum    mineral.silicate.nesosilicate.coarse.tir.gross...
# Name: 386, dtype: object
# Spectrum    mineral.carbonate.none.medium.vswir.c-4a.jpl.p...
# Name: 387, dtype: object
# Spectrum    mineral.silicate.inosilicate.medium.tir.in-5a....
# Name: 388, dtype: object
# Spectrum    mineral.carbonate.none.fine.vswir.c-12a.jpl.pe...
# Name: 389, dtype: object
# Spectrum    mineral.silicate.tectosilicate.coarse.tir.ts-2...
# Name: 390, dtype: object
# Spectrum    mineral.oxide.none.medium.vswir.o-4a.jpl.perki...
# Name: 391, dtype: object
# Spectrum    mineral.silicate.inosilicate.fine.tir.in-1a.jp...
# Name: 392, dtype: object
# Spectrum    mineral.sulfate.none.fine.vswir.so-2b.jpl.beck...
# Name: 393, dtype: object
# Spectrum    mineral.silicate.nesosilicate.solid.tir.montic...
# Name: 394, dtype: object
# Spectrum    mineral.silicate.nesosilicate.solid.tir.datoli...
# Name: 395, dtype: object
# Spectrum    mineral.arsenate.none.medium.vswir.a-1a.jpl.be...
# Name: 396, dtype: object
# Spectrum    mineral.silicate.inosilicate.coarse.tir.rhodon...
# Name: 397, dtype: object
# Spectrum    mineral.carbonate.none.coarse.tir.c-3a.jpl.nic...
# Name: 398, dtype: object
# Spectrum    mineral.oxide.none.fine.vswir.o-15a.jpl.beckma...
# Name: 399, dtype: object
# Spectrum    mineral.silicate.tectosilicate.solid.tir.erion...
# Name: 400, dtype: object
# Spectrum    mineral.silicate.inosilicate.medium.vswir.in-9...
# Name: 401, dtype: object
# Spectrum    mineral.silicate.cyclosilicate.solid.tir.cordi...
# Name: 402, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.vswir.ps-...
# Name: 403, dtype: object
# Spectrum    mineral.carbonate.none.fine.tir.calcite_2.jhu....
# Name: 404, dtype: object
# Spectrum    mineral.carbonate.none.medium.tir.c-3e.jpl.nic...
# Name: 405, dtype: object
# Spectrum    mineral.sulfate.none.medium.vswir.so-8a.jpl.pe...
# Name: 406, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.medium.vswir.p...
# Name: 407, dtype: object
# Spectrum    mineral.sulfate.none.fine.vswir.so-9a.jpl.beck...
# Name: 408, dtype: object
# Spectrum    mineral.oxide.none.fine.tir.ilmenite_1.jhu.nic...
# Name: 409, dtype: object
# Spectrum    mineral.oxide.none.coarse.vswir.o-3a.jpl.perki...
# Name: 410, dtype: object
# Spectrum    mineral.silicate.cyclosilicate.medium.vswir.cs...
# Name: 411, dtype: object
# Spectrum    mineral.silicate.inosilicate.fine.tir.tremol_1...
# Name: 412, dtype: object
# Spectrum    mineral.carbonate.none.coarse.vswir.c-6a.jpl.b...
# Name: 413, dtype: object
# Spectrum    mineral.phosphate.none.medium.vswir.p-3a.jpl.b...
# Name: 414, dtype: object
# Spectrum    mineral.oxide.none.fine.vswir.o-13a.jpl.perkin...
# Name: 415, dtype: object
# Spectrum    mineral.carbonate.none.solid.tir.calcite_1.jhu...
# Name: 416, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.medium.vswir.p...
# Name: 417, dtype: object
# Spectrum    mineral.silicate.inosilicate.medium.vswir.in-2...
# Name: 418, dtype: object
# Spectrum    mineral.silicate.nesosilicate.solid.tir.kyanit...
# Name: 419, dtype: object
# Spectrum    mineral.phosphate.none.coarse.vswir.p-1a.jpl.b...
# Name: 420, dtype: object
# Spectrum    mineral.carbonate.none.medium.vswir.c-4a.jpl.b...
# Name: 421, dtype: object
# Spectrum    mineral.carbonate.none.coarse.tir.calcite_1.jh...
# Name: 422, dtype: object
# Spectrum    mineral.sulfate.none.fine.vswir.so-7b.jpl.beck...
# Name: 423, dtype: object
# Spectrum    mineral.silicate.inosilicate.fine.tir.in-4a.jp...
# Name: 424, dtype: object
# Spectrum    mineral.silicate.tectosilicate.coarse.vswir.ts...
# Name: 425, dtype: object
# Spectrum    mineral.silicate.inosilicate.medium.vswir.in-5...
# Name: 426, dtype: object
# Spectrum    mineral.carbonate.none.coarse.tir.c-6a.jpl.nic...
# Name: 427, dtype: object
# Spectrum    mineral.sulfate.none.fine.tir.barite_1.jhu.nic...
# Name: 428, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.vswir.ps-...
# Name: 429, dtype: object
# Spectrum    mineral.hydroxide.none.fine.vswir.oh-1a.jpl.be...
# Name: 430, dtype: object
# Spectrum    mineral.sulfate.none.fine.tir.alunite_4.jhu.ni...
# Name: 431, dtype: object
# Spectrum    mineral.silicate.cyclosilicate.coarse.tir.cord...
# Name: 432, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.coarse.tir.phl...
# Name: 433, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.coarse.tir.kao...
# Name: 434, dtype: object
# Spectrum    mineral.borate.none.fine.vswir.b-3a.jpl.perkin...
# Name: 435, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.tir.ps-23...
# Name: 436, dtype: object
# Spectrum    mineral.carbonate.none.coarse.vswir.c-3a.jpl.b...
# Name: 437, dtype: object
# Spectrum    mineral.silicate.inosilicate.medium.vswir.in-7...
# Name: 438, dtype: object
# Spectrum    mineral.phosphate.none.coarse.vswir.p-4a.jpl.b...
# Name: 439, dtype: object
# Spectrum    mineral.carbonate.none.medium.vswir.c-1a.jpl.b...
# Name: 440, dtype: object
# Spectrum    mineral.arsenate.none.fine.vswir.a-1a.jpl.beck...
# Name: 441, dtype: object
# Spectrum    mineral.sulfate.none.medium.vswir.so-1a.jpl.pe...
# Name: 442, dtype: object
# Spectrum    mineral.sulfate.none.medium.vswir.so-5a.jpl.be...
# Name: 443, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.coarse.tir.ill...
# Name: 444, dtype: object
# Spectrum    mineral.silicate.nesosilicate.fine.tir.andalus...
# Name: 445, dtype: object
# Spectrum    mineral.silicate.inosilicate.fine.tir.hedenber...
# Name: 446, dtype: object
# Spectrum    mineral.silicate.tectosilicate.medium.vswir.ts...
# Name: 447, dtype: object
# Spectrum    mineral.silicate.nesosilicate.coarse.tir.ns-6a...
# Name: 448, dtype: object
# Spectrum    mineral.silicate.tectosilicate.medium.tir.ts-4...
# Name: 449, dtype: object
# Spectrum    mineral.silicate.inosilicate.coarse.tir.in-3a....
# Name: 450, dtype: object
# Spectrum    mineral.silicate.nesosilicate.coarse.tir.olivi...
# Name: 451, dtype: object
# Spectrum    mineral.silicate.tectosilicate.coarse.vswir.ts...
# Name: 452, dtype: object
# Spectrum    mineral.silicate.tectosilicate.fine.tir.sodali...
# Name: 453, dtype: object
# Spectrum    mineral.carbonate.none.fine.tir.c-3d.jpl.nicol...
# Name: 454, dtype: object
# Spectrum    mineral.sulfide.none.fine.tir.s-9a.jpl.nicolet...
# Name: 455, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.vswir.ps-...
# Name: 456, dtype: object
# Spectrum    mineral.silicate.nesosilicate.coarse.tir.topaz...
# Name: 457, dtype: object
# Spectrum    mineral.tungstate.none.fine.tir.t-1a.jpl.nicol...
# Name: 458, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.medium.tir.ps-...
# Name: 459, dtype: object
# Spectrum    mineral.carbonate.none.medium.vswir.c-11a.jpl....
# Name: 460, dtype: object
# Spectrum    mineral.carbonate.none.medium.tir.c-12a.jpl.ni...
# Name: 461, dtype: object
# Spectrum    mineral.borate.none.medium.vswir.b-4a.jpl.perk...
# Name: 462, dtype: object
# Spectrum    mineral.carbonate.none.medium.tir.c-6a.jpl.nic...
# Name: 463, dtype: object
# Spectrum    mineral.silicate.inosilicate.fine.vswir.in-14a...
# Name: 464, dtype: object
# Spectrum    mineral.silicate.tectosilicate.coarse.tir.anal...
# Name: 465, dtype: object
# Spectrum    mineral.silicate.tectosilicate.medium.vswir.ts...
# Name: 466, dtype: object
# Spectrum    mineral.carbonate.none.medium.vswir.c-9a.jpl.b...
# Name: 467, dtype: object
# Spectrum    mineral.silicate.nesosilicate.medium.vswir.ns-...
# Name: 468, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.vswir.ps-...
# Name: 469, dtype: object
# Spectrum    mineral.silicate.sorosilicate.solid.tir.hemimo...
# Name: 470, dtype: object
# Spectrum    mineral.carbonate.none.fine.tir.dolomite_1.jhu...
# Name: 471, dtype: object
# Spectrum    mineral.sulfate.none.fine.vswir.so-4a.jpl.beck...
# Name: 472, dtype: object
# Spectrum    mineral.sulfide.none.medium.vswir.s-10a.jpl.pe...
# Name: 473, dtype: object
# Spectrum    mineral.silicate.inosilicate.medium.vswir.in-1...
# Name: 474, dtype: object
# Spectrum    mineral.silicate.sorosilicate.fine.vswir.ss-4a...
# Name: 475, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.medium.vswir.p...
# Name: 476, dtype: object
# Spectrum    mineral.sulfate.none.medium.vswir.so-5a.jpl.pe...
# Name: 477, dtype: object
# Spectrum    mineral.carbonate.none.coarse.tir.c-11a.jpl.ni...
# Name: 478, dtype: object
# Spectrum    mineral.silicate.tectosilicate.coarse.tir.albi...
# Name: 479, dtype: object
# Spectrum    mineral.carbonate.none.coarse.vswir.c-3e.jpl.b...
# Name: 480, dtype: object
# Spectrum    mineral.carbonate.none.fine.vswir.c-7a.jpl.bec...
# Name: 481, dtype: object
# Spectrum    mineral.halide.none.fine.vswir.h-4a.jpl.perkin...
# Name: 482, dtype: object
# Spectrum    mineral.borate.none.coarse.vswir.b-3a.jpl.perk...
# Name: 483, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.medium.vswir.p...
# Name: 484, dtype: object
# Spectrum    mineral.silicate.sorosilicate.coarse.tir.clino...
# Name: 485, dtype: object
# Spectrum    mineral.silicate.tectosilicate.coarse.tir.sani...
# Name: 486, dtype: object
# Spectrum    mineral.oxide.none.solid.tir.rutile_1.jhu.nico...
# Name: 487, dtype: object
# Spectrum    mineral.silicate.tectosilicate.coarse.vswir.ts...
# Name: 488, dtype: object
# Spectrum    mineral.silicate.cyclosilicate.medium.vswir.cs...
# Name: 489, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.coarse.tir.mus...
# Name: 490, dtype: object
# Spectrum    mineral.silicate.inosilicate.medium.tir.in-8a....
# Name: 491, dtype: object
# Spectrum    mineral.halide.none.solid.tir.flourite_1.jhu.n...
# Name: 492, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.solid.tir.clin...
# Name: 493, dtype: object
# Spectrum    mineral.silicate.tectosilicate.coarse.tir.micr...
# Name: 494, dtype: object
# Spectrum    mineral.silicate.nesosilicate.solid.tir.spessa...
# Name: 495, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.solid.tir.pyro...
# Name: 496, dtype: object
# Spectrum    mineral.sulfide.none.fine.tir.s-1a.jpl.nicolet...
# Name: 497, dtype: object
# Spectrum    mineral.silicate.tectosilicate.fine.tir.ts-6a....
# Name: 498, dtype: object
# Spectrum    mineral.borate.none.fine.tir.b-6a.jpl.nicolet....
# Name: 499, dtype: object
# Spectrum    mineral.oxide.none.fine.tir.rutile_1.jhu.nicol...
# Name: 500, dtype: object
# Spectrum    mineral.silicate.tectosilicate.fine.vswir.ts-1...
# Name: 501, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.tir.ps-3a...
# Name: 502, dtype: object
# Spectrum    mineral.silicate.tectosilicate.solid.tir.ortho...
# Name: 503, dtype: object
# Spectrum    mineral.silicate.nesosilicate.coarse.tir.alman...
# Name: 504, dtype: object
# Spectrum    mineral.phosphate.none.fine.vswir.p-2a.jpl.per...
# Name: 505, dtype: object
# Spectrum    mineral.silicate.tectosilicate.coarse.vswir.ts...
# Name: 506, dtype: object
# Spectrum    mineral.carbonate.none.medium.vswir.c-9a.jpl.p...
# Name: 507, dtype: object
# Spectrum    mineral.sulfate.none.medium.vswir.so-9a.jpl.pe...
# Name: 508, dtype: object
# Spectrum    mineral.silicate.sorosilicate.medium.vswir.ss-...
# Name: 509, dtype: object
# Spectrum    mineral.oxide.none.coarse.vswir.o-2a.jpl.perki...
# Name: 510, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.vswir.ps-...
# Name: 511, dtype: object
# Spectrum    mineral.silicate.sorosilicate.medium.vswir.ss-...
# Name: 512, dtype: object
# Spectrum    mineral.silicate.tectosilicate.solid.tir.nephe...
# Name: 513, dtype: object
# Spectrum    mineral.silicate.tectosilicate.coarse.tir.anor...
# Name: 514, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.medium.vswir.p...
# Name: 515, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.tir.sapon...
# Name: 516, dtype: object
# Spectrum    mineral.halide.none.coarse.tir.h-2a.jpl.nicole...
# Name: 517, dtype: object
# Spectrum    mineral.silicate.nesosilicate.fine.tir.montice...
# Name: 518, dtype: object
# Spectrum    mineral.sulfide.none.fine.vswir.s-7a.jpl.beckm...
# Name: 519, dtype: object
# Spectrum    mineral.oxide.none.fine.vswir.o-12a.jpl.perkin...
# Name: 520, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.medium.vswir.p...
# Name: 521, dtype: object
# Spectrum    mineral.phosphate.none.medium.tir.p-4a.jpl.nic...
# Name: 522, dtype: object
# Spectrum    mineral.silicate.tectosilicate.fine.tir.labrad...
# Name: 523, dtype: object
# Spectrum    mineral.sulfate.none.medium.tir.so-8a.jpl.nico...
# Name: 524, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.vswir.ps-...
# Name: 525, dtype: object
# Spectrum    mineral.silicate.sorosilicate.fine.tir.epidote...
# Name: 526, dtype: object
# Spectrum    mineral.silicate.inosilicate.coarse.tir.spodum...
# Name: 527, dtype: object
# Spectrum    mineral.silicate.tectosilicate.solid.tir.quart...
# Name: 528, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.medium.tir.ps-...
# Name: 529, dtype: object
# Spectrum    mineral.carbonate.none.medium.tir.c-3d.jpl.nic...
# Name: 530, dtype: object
# Spectrum    mineral.sulfate.none.solid.tir.gypsum_1.jhu.ni...
# Name: 531, dtype: object
# Spectrum    mineral.halide.none.fine.tir.h-1a.jpl.nicolet....
# Name: 532, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.tir.ps-10...
# Name: 533, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.coarse.tir.chr...
# Name: 534, dtype: object
# Spectrum    mineral.silicate.tectosilicate.coarse.vswir.ts...
# Name: 535, dtype: object
# Spectrum    mineral.oxide.none.fine.vswir.o-1b.jpl.beckman...
# Name: 536, dtype: object
# Spectrum    mineral.carbonate.none.medium.vswir.c-5a.jpl.p...
# Name: 537, dtype: object
# Spectrum    mineral.silicate.nesosilicate.fine.tir.andradi...
# Name: 538, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.coarse.tir.mon...
# Name: 539, dtype: object
# Spectrum    mineral.borate.none.medium.tir.b-1a.jpl.nicole...
# Name: 540, dtype: object
# Spectrum    mineral.silicate.tectosilicate.coarse.tir.ts-1...
# Name: 541, dtype: object
# Spectrum    mineral.oxide.none.medium.vswir.o-8a.jpl.beckm...
# Name: 542, dtype: object
# Spectrum    mineral.carbonate.none.medium.vswir.c-10a.jpl....
# Name: 543, dtype: object
# Spectrum    mineral.sulfate.none.fine.tir.so-3a.jpl.nicole...
# Name: 544, dtype: object
# Spectrum    mineral.oxide.none.coarse.tir.o-3a.jpl.nicolet...
# Name: 545, dtype: object
# Spectrum    mineral.carbonate.none.coarse.vswir.c-2a.jpl.p...
# Name: 546, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.coarse.tir.bio...
# Name: 547, dtype: object
# Spectrum    mineral.silicate.inosilicate.fine.vswir.in-4a....
# Name: 548, dtype: object
# Spectrum    mineral.silicate.nesosilicate.fine.vswir.ns-1a...
# Name: 549, dtype: object
# Spectrum    mineral.carbonate.none.coarse.vswir.c-5c.jpl.b...
# Name: 550, dtype: object
# Spectrum    mineral.halide.none.medium.tir.h-2a.jpl.nicole...
# Name: 551, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.medium.vswir.p...
# ...
# Name: 1427, dtype: object
# Spectrum    mineral.silicate.tectosilicate.fine.tir.ts-17a...
# Name: 1428, dtype: object
# Spectrum    mineral.silicate.nesosilicate.fine.vswir.ns-7a...
# Name: 1429, dtype: object
# Spectrum    mineral.element.none.fine.vswir.e-2a.jpl.beckm...
# Name: 1430, dtype: object
# Spectrum    mineral.oxide.none.medium.vswir.o-6a.jpl.perki...
# Name: 1431, dtype: object
# Spectrum    mineral.silicate.nesosilicate.medium.vswir.ns-...
# Name: 1432, dtype: object
# Spectrum    mineral.halide.none.medium.vswir.h-1a.jpl.beck...
# Name: 1433, dtype: object
# Spectrum    mineral.silicate.tectosilicate.fine.tir.leucit...
# Name: 1434, dtype: object
# Spectrum    mineral.sulfide.none.coarse.tir.s-5a.jpl.nicol...
# Name: 1435, dtype: object
# Spectrum    mineral.silicate.tectosilicate.medium.vswir.ts...
# Name: 1436, dtype: object
# Spectrum    mineral.silicate.tectosilicate.fine.tir.ts-10a...
# Name: 1437, dtype: object
# Spectrum    mineral.halide.none.coarse.vswir.h-3a.jpl.beck...
# Name: 1438, dtype: object
# Spectrum    mineral.silicate.sorosilicate.medium.vswir.ss-...
# Name: 1439, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.medium.vswir.p...
# Name: 1440, dtype: object
# Spectrum    mineral.sulfate.none.medium.tir.so-3a.jpl.nico...
# Name: 1441, dtype: object
# Spectrum    mineral.oxide.none.coarse.vswir.o-1a.jpl.perki...
# Name: 1442, dtype: object
# Spectrum    mineral.silicate.sorosilicate.coarse.vswir.ss-...
# Name: 1443, dtype: object
# Spectrum    mineral.silicate.sorosilicate.medium.tir.ss-3a...
# Name: 1444, dtype: object
# Spectrum    mineral.halide.none.medium.tir.h-1a.jpl.nicole...
# Name: 1445, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.tir.kaoli...
# Name: 1446, dtype: object
# Spectrum    mineral.halide.none.coarse.tir.h-2b.jpl.nicole...
# Name: 1447, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.medium.vswir.p...
# Name: 1448, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.coarse.vswir.p...
# Name: 1449, dtype: object
# Spectrum    mineral.oxide.none.fine.vswir.o-11a.jpl.perkin...
# Name: 1450, dtype: object
# Spectrum    mineral.oxide.none.coarse.vswir.o-11a.jpl.perk...
# Name: 1451, dtype: object
# Spectrum    mineral.silicate.nesosilicate.solid.tir.stauro...
# Name: 1452, dtype: object
# Spectrum    mineral.silicate.inosilicate.fine.tir.in-14a.j...
# Name: 1453, dtype: object
# Spectrum    mineral.sulfide.none.medium.vswir.s-7a.jpl.bec...
# Name: 1454, dtype: object
# Spectrum    mineral.sulfate.none.coarse.vswir.so-2b.jpl.be...
# Name: 1455, dtype: object
# Spectrum    mineral.borate.none.coarse.tir.b-2a.jpl.nicole...
# Name: 1456, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.coarse.tir.mon...
# Name: 1457, dtype: object
# Spectrum    mineral.arsenate.none.fine.tir.a-1a.jpl.nicole...
# Name: 1458, dtype: object
# Spectrum    mineral.sulfide.none.coarse.vswir.s-5a.jpl.bec...
# Name: 1459, dtype: object
# Spectrum    mineral.silicate.tectosilicate.fine.vswir.ts-1...
# Name: 1460, dtype: object
# Spectrum    mineral.silicate.sorosilicate.fine.tir.ss-2a.j...
# Name: 1461, dtype: object
# Spectrum    mineral.carbonate.none.coarse.vswir.c-1a.jpl.p...
# Name: 1462, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.coarse.tir.bio...
# Name: 1463, dtype: object
# Spectrum    mineral.sulfate.none.medium.vswir.so-7b.jpl.pe...
# Name: 1464, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.vswir.ps-...
# Name: 1465, dtype: object
# Spectrum    mineral.silicate.cyclosilicate.fine.vswir.cs-2...
# Name: 1466, dtype: object
# Spectrum    mineral.silicate.nesosilicate.medium.vswir.ns-...
# Name: 1467, dtype: object
# Spectrum    mineral.silicate.tectosilicate.medium.tir.ts-1...
# Name: 1468, dtype: object
# Spectrum    mineral.sulfate.none.solid.tir.gypsum_2.jhu.ni...
# Name: 1469, dtype: object
# Spectrum    mineral.carbonate.none.fine.tir.c-5a.jpl.nicol...
# Name: 1470, dtype: object
# Spectrum    mineral.borate.none.coarse.vswir.b-5a.jpl.beck...
# Name: 1471, dtype: object
# Spectrum    mineral.sulfate.none.coarse.vswir.so-9a.jpl.be...
# Name: 1472, dtype: object
# Spectrum    mineral.oxide.none.medium.vswir.o-3a.jpl.beckm...
# Name: 1473, dtype: object
# Spectrum    mineral.silicate.tectosilicate.coarse.tir.ts-1...
# Name: 1474, dtype: object
# Spectrum    mineral.sulfate.none.fine.tir.so-8a.jpl.nicole...
# Name: 1475, dtype: object
# Spectrum    mineral.oxide.none.coarse.tir.o-8a.jpl.nicolet...
# Name: 1476, dtype: object
# Spectrum    mineral.carbonate.none.fine.tir.aragonite_1.jh...
# Name: 1477, dtype: object
# Spectrum    mineral.oxide.none.fine.vswir.o-1a.jpl.beckman...
# Name: 1478, dtype: object
# Spectrum    mineral.carbonate.none.medium.vswir.c-6a.jpl.p...
# Name: 1479, dtype: object
# Spectrum    mineral.oxide.none.coarse.vswir.o-1a.jpl.beckm...
# Name: 1480, dtype: object
# Spectrum    mineral.carbonate.none.fine.vswir.c-10a.jpl.pe...
# Name: 1481, dtype: object
# Spectrum    mineral.oxide.none.solid.tir.chromite_1.jhu.ni...
# Name: 1482, dtype: object
# Spectrum    mineral.halide.none.medium.vswir.h-2b.jpl.beck...
# Name: 1483, dtype: object
# Spectrum    mineral.sulfide.none.medium.tir.s-5a.jpl.nicol...
# Name: 1484, dtype: object
# Spectrum    mineral.carbonate.none.coarse.all.traonac.usgs...
# Name: 1485, dtype: object
# Spectrum    mineral.silicate.tectosilicate.coarse.tir.heul...
# Name: 1486, dtype: object
# Spectrum    mineral.silicate.sorosilicate.fine.vswir.ss-1c...
# Name: 1487, dtype: object
# Spectrum    mineral.oxide.none.medium.vswir.o-2a.jpl.perki...
# Name: 1488, dtype: object
# Spectrum    mineral.sulfate.none.coarse.vswir.so-11a.jpl.p...
# Name: 1489, dtype: object
# Spectrum    mineral.oxide.none.coarse.vswir.o-15a.jpl.perk...
# Name: 1490, dtype: object
# Spectrum    mineral.silicate.tectosilicate.fine.tir.ts-18a...
# Name: 1491, dtype: object
# Spectrum    mineral.halide.none.coarse.tir.h-1a.jpl.nicole...
# Name: 1492, dtype: object
# Spectrum    mineral.halide.none.medium.tir.h-2b.jpl.nicole...
# Name: 1493, dtype: object
# Spectrum    mineral.oxide.none.fine.vswir.o-15a.jpl.perkin...
# Name: 1494, dtype: object
# Spectrum    mineral.silicate.inosilicate.coarse.vswir.in-3...
# Name: 1495, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.medium.vswir.p...
# Name: 1496, dtype: object
# Spectrum    mineral.sulfide.none.fine.vswir.s-4a.jpl.beckm...
# Name: 1497, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.coarse.tir.ps-...
# Name: 1498, dtype: object
# Spectrum    mineral.oxide.none.fine.tir.o-3a.jpl.nicolet.s...
# Name: 1499, dtype: object
# Spectrum    mineral.silicate.cyclosilicate.coarse.vswir.cs...
# Name: 1500, dtype: object
# Spectrum    mineral.halide.none.fine.vswir.h-2b.jpl.perkin...
# Name: 1501, dtype: object
# Spectrum    mineral.silicate.nesosilicate.fine.tir.olivine...
# Name: 1502, dtype: object
# Spectrum    mineral.carbonate.none.coarse.vswir.c-5a.jpl.p...
# Name: 1503, dtype: object
# Spectrum    mineral.silicate.inosilicate.fine.vswir.in-7a....
# Name: 1504, dtype: object
# Spectrum    mineral.silicate.nesosilicate.fine.vswir.ns-2a...
# Name: 1505, dtype: object
# Spectrum    mineral.silicate.cyclosilicate.fine.vswir.cs-1...
# Name: 1506, dtype: object
# Spectrum    mineral.borate.none.medium.tir.b-2a.jpl.nicole...
# Name: 1507, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.tir.ps-18...
# Name: 1508, dtype: object
# Spectrum    mineral.silicate.inosilicate.fine.tir.spodum_1...
# Name: 1509, dtype: object
# Spectrum    mineral.sulfate.none.coarse.vswir.so-1a.jpl.be...
# Name: 1510, dtype: object
# Spectrum    mineral.silicate.nesosilicate.solid.tir.almand...
# Name: 1511, dtype: object
# Spectrum    mineral.carbonate.none.medium.vswir.c-2a.jpl.p...
# Name: 1512, dtype: object
# Spectrum    mineral.oxide.none.medium.tir.o-8a.jpl.nicolet...
# Name: 1513, dtype: object
# Spectrum    mineral.silicate.tectosilicate.fine.tir.micro_...
# Name: 1514, dtype: object
# Spectrum    mineral.silicate.nesosilicate.medium.vswir.ns-...
# Name: 1515, dtype: object
# Spectrum    mineral.oxide.none.fine.tir.o-13a.jpl.nicolet....
# Name: 1516, dtype: object
# Spectrum    mineral.silicate.tectosilicate.fine.vswir.ts-3...
# Name: 1517, dtype: object
# Spectrum    mineral.silicate.sorosilicate.fine.vswir.ss-1c...
# Name: 1518, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.vswir.ps-...
# Name: 1519, dtype: object
# Spectrum    mineral.borate.none.fine.vswir.b-3a.jpl.beckma...
# Name: 1520, dtype: object
# Spectrum    mineral.carbonate.none.coarse.tir.dolomite_1.j...
# Name: 1521, dtype: object
# Spectrum    mineral.halide.none.fine.tir.h-2a.jpl.nicolet....
# Name: 1522, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.tir.ps-13...
# Name: 1523, dtype: object
# Spectrum    mineral.oxide.none.coarse.vswir.o-15a.jpl.beck...
# Name: 1524, dtype: object
# Spectrum    mineral.silicate.inosilicate.fine.tir.enstatit...
# Name: 1525, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.coarse.vswir.p...
# Name: 1526, dtype: object
# Spectrum    mineral.silicate.sorosilicate.medium.vswir.ss-...
# Name: 1527, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.coarse.tir.phl...
# Name: 1528, dtype: object
# Spectrum    mineral.silicate.inosilicate.solid.tir.spodum_...
# Name: 1529, dtype: object
# Spectrum    mineral.borate.none.coarse.vswir.b-4a.jpl.perk...
# Name: 1530, dtype: object
# Spectrum    mineral.halide.none.fine.vswir.h-3a.jpl.perkin...
# Name: 1531, dtype: object
# Spectrum    mineral.carbonate.none.coarse.tir.c-12a.jpl.ni...
# Name: 1532, dtype: object
# Spectrum    mineral.sulfate.none.solid.tir.anhydrite_1.jhu...
# Name: 1533, dtype: object
# Spectrum    mineral.carbonate.none.fine.vswir.c-4a.jpl.bec...
# Name: 1534, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.tir.clino...
# Name: 1535, dtype: object
# Spectrum    mineral.carbonate.none.coarse.tir.calcite_2.jh...
# Name: 1536, dtype: object
# Spectrum    mineral.sulfate.none.fine.vswir.so-7a.jpl.beck...
# Name: 1537, dtype: object
# Spectrum    mineral.silicate.inosilicate.fine.tir.bustamit...
# Name: 1538, dtype: object
# Spectrum    mineral.borate.none.coarse.all.nmnh123943.usgs...
# Name: 1539, dtype: object
# Spectrum    mineral.silicate.inosilicate.medium.vswir.in-6...
# Name: 1540, dtype: object
# Spectrum    mineral.carbonate.none.coarse.vswir.c-8a.jpl.b...
# Name: 1541, dtype: object
# Spectrum    mineral.silicate.nesosilicate.medium.vswir.ns-...
# Name: 1542, dtype: object
# Spectrum    mineral.carbonate.none.medium.tir.c-5a.jpl.nic...
# Name: 1543, dtype: object
# Spectrum    mineral.carbonate.none.medium.tir.c-11a.jpl.ni...
# Name: 1544, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.vswir.ps-...
# Name: 1545, dtype: object
# Spectrum    mineral.silicate.tectosilicate.medium.vswir.ts...
# Name: 1546, dtype: object
# Spectrum    mineral.borate.none.medium.vswir.b-3a.jpl.perk...
# Name: 1547, dtype: object
# Spectrum    mineral.silicate.inosilicate.fine.vswir.in-13a...
# Name: 1548, dtype: object
# Spectrum    mineral.silicate.nesosilicate.coarse.tir.olivi...
# Name: 1549, dtype: object
# Spectrum    mineral.silicate.tectosilicate.coarse.vswir.ts...
# Name: 1550, dtype: object
# Spectrum    mineral.silicate.nesosilicate.solid.tir.andalu...
# Name: 1551, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.coarse.tir.sap...
# Name: 1552, dtype: object
# Spectrum    mineral.silicate.tectosilicate.coarse.tir.orth...
# Name: 1553, dtype: object
# Spectrum    mineral.silicate.tectosilicate.coarse.tir.erio...
# Name: 1554, dtype: object
# Spectrum    mineral.silicate.tectosilicate.fine.vswir.ts-1...
# Name: 1555, dtype: object
# Spectrum    mineral.silicate.nesosilicate.coarse.tir.spess...
# Name: 1556, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.vswir.ps-...
# Name: 1557, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.medium.vswir.p...
# Name: 1558, dtype: object
# Spectrum    mineral.carbonate.none.medium.vswir.c-12a.jpl....
# Name: 1559, dtype: object
# Spectrum    mineral.silicate.inosilicate.coarse.tir.in-8a....
# Name: 1560, dtype: object
# Spectrum    mineral.silicate.nesosilicate.fine.tir.ns-6a.j...
# Name: 1561, dtype: object
# Spectrum    mineral.sulfate.none.coarse.vswir.so-7c.jpl.be...
# Name: 1562, dtype: object
# Spectrum    mineral.borate.none.fine.tir.b-5a.jpl.nicolet....
# Name: 1563, dtype: object
# Spectrum    mineral.carbonate.none.coarse.vswir.c-9a.jpl.p...
# Name: 1564, dtype: object
# Spectrum    mineral.silicate.tectosilicate.fine.tir.ts-5a....
# Name: 1565, dtype: object
# Spectrum    mineral.sulfide.none.fine.tir.s-2a.jpl.nicolet...
# Name: 1566, dtype: object
# Spectrum    mineral.silicate.cyclosilicate.medium.vswir.cs...
# Name: 1567, dtype: object
# Spectrum    mineral.silicate.cyclosilicate.fine.tir.cordie...
# Name: 1568, dtype: object
# Spectrum    mineral.sulfate.none.medium.vswir.so-6a.jpl.pe...
# Name: 1569, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.tir.ps-20...
# Name: 1570, dtype: object
# Spectrum    mineral.carbonate.none.medium.vswir.c-2a.jpl.b...
# Name: 1571, dtype: object
# Spectrum    mineral.arsenate.none.fine.vswir.a-2a.jpl.beck...
# Name: 1572, dtype: object
# Spectrum    mineral.borate.none.fine.vswir.b-4a.jpl.perkin...
# Name: 1573, dtype: object
# Spectrum    mineral.silicate.inosilicate.medium.vswir.in-4...
# Name: 1574, dtype: object
# Spectrum    mineral.sulfate.none.fine.tir.alunite_3.jhu.ni...
# Name: 1575, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.medium.vswir.p...
# Name: 1576, dtype: object
# Spectrum    mineral.silicate.cyclosilicate.medium.vswir.cs...
# Name: 1577, dtype: object
# Spectrum    mineral.oxide.none.fine.vswir.o-13a.jpl.beckma...
# Name: 1578, dtype: object
# Spectrum    mineral.carbonate.none.coarse.tir.c-5a.jpl.nic...
# Name: 1579, dtype: object
# Spectrum    mineral.hydroxide.none.fine.vswir.oh-2a.jpl.be...
# Name: 1580, dtype: object
# Spectrum    mineral.carbonate.none.fine.tir.dolomite_2.jhu...
# Name: 1581, dtype: object
# Spectrum    mineral.silicate.inosilicate.fine.tir.in-7a.jp...
# Name: 1582, dtype: object
# Spectrum    mineral.silicate.inosilicate.medium.vswir.in-2...
# Name: 1583, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.coarse.vswir.p...
# Name: 1584, dtype: object
# Spectrum    mineral.silicate.tectosilicate.coarse.vswir.ts...
# Name: 1585, dtype: object
# Spectrum    mineral.silicate.tectosilicate.coarse.vswir.ts...
# Name: 1586, dtype: object
# Spectrum    mineral.silicate.tectosilicate.solid.tir.natro...
# Name: 1587, dtype: object
# Spectrum    mineral.silicate.nesosilicate.coarse.tir.topaz...
# Name: 1588, dtype: object
# Spectrum    mineral.hydroxide.none.medium.vswir.oh-1a.jpl....
# Name: 1589, dtype: object
# Spectrum    mineral.silicate.tectosilicate.coarse.tir.ts-4...
# Name: 1590, dtype: object
# Spectrum    mineral.sulfide.none.fine.vswir.s-10a.jpl.perk...
# Name: 1591, dtype: object
# Spectrum    mineral.silicate.nesosilicate.medium.tir.ns-6a...
# Name: 1592, dtype: object
# Spectrum    mineral.silicate.inosilicate.medium.tir.in-3a....
# Name: 1593, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.vswir.ps-...
# Name: 1594, dtype: object
# Spectrum    mineral.silicate.nesosilicate.coarse.vswir.ns-...
# Name: 1595, dtype: object
# Spectrum    mineral.phosphate.none.fine.vswir.p-1a.jpl.per...
# Name: 1596, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.coarse.tir.liz...
# Name: 1597, dtype: object
# Spectrum    mineral.silicate.tectosilicate.coarse.vswir.ts...
# Name: 1598, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.solid.tir.talc...
# Name: 1599, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.vswir.ps-...
# Name: 1600, dtype: object
# Spectrum    mineral.sulfide.none.coarse.vswir.s-10a.jpl.be...
# Name: 1601, dtype: object
# Spectrum    mineral.silicate.tectosilicate.medium.vswir.ts...
# Name: 1602, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.coarse.tir.mus...
# Name: 1603, dtype: object
# Spectrum    mineral.sulfate.none.fine.tir.so-10a.jpl.nicol...
# Name: 1604, dtype: object
# Spectrum    mineral.silicate.phyllosilicate.fine.tir.sepio...
# Name: 1605, dtype: object
# Spectrum    mineral.sulfate.none.medium.vswir.so-6a.jpl.be...
# Name: 1606, dtype: object
# Spectrum    mineral.silicate.nesosilicate.solid.tir.olivin...
# Name: 1607, dtype: object
# Spectrum    mineral.silicate.sorosilicate.fine.vswir.ss-3a...
# Name: 1608, dtype: object

# %%
i = 0
for row in metadata.itertuples():
    print(i)
    i = i + 1
#     print(row.Spectrum)
#     print(row.Spectrum) # or iterrows() (returns index and row) and then row["Spectrum"]
    data = pd.read_csv(os.path.join(data_path, row.Spectrum), sep = "\s+", header=None, skipinitialspace=True, skiprows=21)
    fi = open(row.Spectrum, "r")
#     print(fi.readline().strip().split()[1])
    print(fi.readline())
# Out:
# 0
# Name: Hypersthene (Mg,Fe+2)2Si2O6
#
# 1
# Name: Ilmenite Fe+2TiO3
#
# 2
# Name: Staurolite (Fe+2,Mg,Zn)2Al9(Si,Al)4O22(OH)2
#
# 3
# Name: Calcite CaCO_3
#
# 4
# Name: Phlogopite KMg3Si3Al010(F,OH)2
#
# 5
# Name: Tremolite Ca_2(Mg,Fe^2+)_5Si_8O_22(OH)_2
#
# 6
# Name: Wollastonite CaSiO3
#
# 7
# Name: Triphylite Li(Mn,Fe)PO_4
#
# 8
# Name: Strontianite SrCO_3
#
# 9
# Name: Anhydrite CaSO_4
#
# 10
# Name: Prehnite Ca_2Al_2Si_3O_10(OH)_2
#
# 11
# Name: Cummingtonite (Mg,Fe^2+)_7Si_8O_22(OH)_2
#
# 12
# Name: Sulphur S
#
# 13
# Name: Tremolite Ca_2(Mg,Fe^2+)_5Si_8O_22(OH)_2
#
# 14
# Name: Gibbsite Al(OH)_3
#
# 15
# Name: Alunite KAl_3(SO_4)_2(OH)_6
#
# 16
# Name: Chalcopyrite CuFeS_2
#
# 17
# Name: Olivine (Fo88) (Fe+2,Mg)2SiO4
#
# 18
# Name: Scorodite Fe^3+AsO_4.2H_2O
#
# 19
# Name: Quartz SiO_2
#
# 20
# Name: Anatase TiO_2
#
# 21
# Name: Trona Na_3(CO_3)(HCO_3).2H_2O
#
# 22
# Name: Quartz SiO_2
#
# 23
# Name: Chalcopyrite CuFeS_2
#
# 24
# Name: Anorthite (Feldspar) (NaSi,CaAl)AlSi_2O_8
#
# 25
# Name: Titanite (Sphene) CaTiSiO_5
#
# 26
# Name: Wollastonite CaSiO_3
#
# 27
# Name: Zoisite (var. tanzanite) Ca2Al3(SiO4)3(OH)
#
# 28
# Name: Titanite (Sphene) CaTiSiO_5
#
# 29
# Name: Stilbite NaCa_2Al_5Si_3O_36.14H_2O
#
# 30
# Name: Wollastonite CaSiO3
#
# 31
# Name: Smithsonite PbCO_3
#
# 32
# Name: Chlorite (Mg,Al)_6(Si,Al)_4O_10(OH)_8
#
# 33
# Name: Montmorillonite (Na,Ca)_0.33(Al,Mg)_2Si_4O_10(OH)_2.H_2O
#
# 34
# Name: Goethite a-Fe+3O(OH)
#
# 35
# Name: Augite (Ca,Na)(Mg,Fe,Al,Ti)(Si,Al)2O6
#
# 36
# Name: Jarosite KFe_3^3+(SO_4)_2(OH)_6
#
# 37
# Name: Cassiterite SnO_2
#
# 38
# Name: Antlerite Cu_3(SO_4)(OH)_4
#
# 39
# Name: Realgar AsS
#
# 40
# Name: Albite (Feldspar) (K,Na)AlSi_3O_8
#
# 41
# Name: Almandine Garnet Fe_3Al_2(SiO_4)_3
#
# 42
# Name: Rhodonite (Mn,Ca)SiO_3
#
# 43
# Name: Quartz SiO_2
#
# 44
# Name: Diopside CaMg(SiO_3)_2
#
# 45
# Name: Illite/smectite (K,H3O)(Al,Mg,Fe)2(Si,Al)4 O10 [(OH)2,H2O]
#
# 46
# Name: Labradorite (Feldspar) (NaSi,CaAl)AlSi_2O_8
#
# 47
# Name: Topaz Al2SiO4(F,OH)2
#
# 48
# Name: Molybdenite MoS_2
#
# 49
# Name: Cookeite LiAl_4(Si_3Al)O_10(OH)_8
#
# 50
# Name: Quartz SiO2
#
# 51
# Name: Celestite SrSO_4
#
# 52
# Name: Dolomite CaMg(CO_3)_2
#
# 53
# Name: Anhydrite CaSO4
#
# 54
# Name: Calcite CaCO_3
#
# 55
# Name: Tourmaline (Elbaite) Na(Li,Al)3Al6(BO3)3Si6018(OH)4
#
# 56
# Name: Glauconite (K,Na)(Fe^3+,Al,Mg)_2(Si,Al)_4O_10(OH)_2
#
# 57
# Name: Pyrophyllite Al_2Si_4O_10(OH)_2
#
# 58
# Name: Fayalite Fe_2SiO_4
#
# 59
# Name: Barite, BaSO4
#
# 60
# Name: Nepheline (Na,K)AlSiO4
#
# 61
# Name: Leucite KAlSi2O6
#
# 62
# Name: Augite (Ca,Na)(Mg,Fe,Al,Ti)(Si,Al)2O6
#
# 63
# Name: Scorodite Fe^3+AsO_4.2H_2O
#
# 64
# Name: Dolomite CaMg(CO_3)_2
#
# 65
# Name: Siderite Fe^2+CO_3
#
# 66
# Name: Trona Na_3(CO_3)(HCO_3).2H_2O
#
# 67
# Name: Topaz Al_2SiO_4(F,OH)_2
#
# 68
# Name: Cerussite PbCO_3
#
# 69
# Name: Rhodonite (Mn,Ca)SiO_3
#
# 70
# Name: Diopside CaMgSi2O6
#
# 71
# Name: Marcasite FeS_2
#
# 72
# Name: Hematite a-Fe2O3
#
# 73
# Name: Tschermigite (NH_4)Al(SO_4)_2.12H_2O
#
# 74
# Name: Olivine (Fo88) (Fe+2,Mg)2SiO4
#
# 75
# Name: Sodalite Na8Al6Si6O24Cl2
#
# 76
# Name: Gypsum CaSO4 * 2H2O
#
# 77
# Name: Sanidine (Feldspar) (K,Na)AlSi_3O_8
#
# 78
# Name: Kaolinite Al_2Si_2O_5(OH)_4
#
# 79
# Name: Anhydrite CaSO4
#
# 80
# Name: Anorthite (Feldspar) (NaSi,CaAl)AlSi_2O_8
#
# 81
# Name: Ferroaxinite Ca_2Fe^2+Al_2BSi_4O_15(OH)
#
# 82
# Name: Cordierite Mg_2Al_3(Si_5Al)O_18
#
# 83
# Name: Quartz SiO_2
#
# 84
# Name: Natrojarosite NaFe_3^3+(SO_4)_2(OH)_6
#
# 85
# Name: Tincalconite Na_2B_4O_5(OH)_4.3H_2O
#
# 86
# Name: Galena PbS
#
# 87
# Name: Columbite Fe^2+Nb_2O_6
#
# 88
# Name: Andesine (Feldspar) (NaSi,CaAl)AlSi_2O_8
#
# 89
# Name: Realgar AsS
#
# 90
# Name: Diopside CaMgSi2O6
#
# 91
# Name: Tourmaline (Schorl) NaFe3+2Al6(BO3)3Si6O18(OH)4
#
# 92
# Name: Labradorite (Feldspar) (NaSi,CaAl)AlSi_2O_8
#
# 93
# Name: Titanite (Sphene) CaTiSiO_5
#
# 94
# Name: Olivine (Fo92) (Fe+2,Mg)2SiO4
#
# 95
# Name: Gypsum CaSO_4.2H_2O
#
# 96
# Name: Cummingtonite (Mg,Fe^2+)_7Si_8O_22(OH)_2
#
# 97
# Name: Phlogopite KMg3Si3Al010(F,OH)2
#
# 98
# Name: Diopside CaMg(SiO_3)_2
#
# 99
# Name: Fluorite CaF_2
#
# 100
# Name: Pyrrhotite Fe(1-x)S
#
# 101
# Name: Montmorillonite (Na,Ca)_0.33(Al,Mg)_2Si_4O_10(OH)_2.H_2O
#
# 102
# Name: Chalcopyrite CuFeS_2
#
# 103
# Name: Olivine (Fo41) (Fe+2,Mg)2SiO4
#
# 104
# Name: Corundum Al_2O_3
#
# 105
# Name: Hornblende Ca2(Fe+2,Mg)4Al(Si7Al)O22(OH,F)2
#
# 106
# Name: Sulphur S
#
# 107
# Name: Calcite CaCO_3
#
# 108
# Name: Epidote Ca_2(Al,Fe^3+)_3O.SiO_4.Si_2O_7.OH
#
# 109
# Name: Beryl Be_3Al_2Si_6O_18
#
# 110
# Name: Aphthitalite (K,Na)_3Na(SO_4)_2
#
# 111
# Name: Calcite CaCO_3
#
# 112
# Name: Rutile TiO_2
#
# 113
# Name: Oligoclase (Feldspar) (NaSi,CaAl)AlSi_2O_8
#
# 114
# Name: Hydroxyapophyllite KCa_4Si_8O_20(OH,F).8H_2O
#
# 115
# Name: Wollastonite CaSiO_3
#
# 116
# Name: Muscovite KAl2(Si3Al)O10(OH,F)2
#
# 117
# Name: Arsenopyrite FeAsS
#
# 118
# Name: Fluorite CaF_2
#
# 119
# Name: Ulexite NaCaB_5O_6(OH)_6.5H_2O
#
# 120
# Name: Alunite (potassium alunite) KAl3(SO4)2(OH)6
#
# 121
# Name: Montmorillonite (Na,Ca)0.33(Al,Mg)2Si4O10(OH)2.nH2O
#
# 122
# Name: Quartz SiO_2
#
# 123
# Name: Vermiculite (Mg,Fe^2+,Al)_3(Al,Si)_4O_10(OH)_2.4H_2O
#
# 124
# Name: Sanidine (K,Na)Al3O8
#
# 125
# Name: Chrysotile Mg3Si2O5(OH)4
#
# 126
# Name: Magnesiochromite MgCr_2O_4
#
# 127
# Name: Cummingtonite (Mg,Fe^2+)_7Si_8O_22(OH)_2
#
# 128
# Name: Cookeite LiAl_4(Si_3Al)O_10(OH)_8
#
# 129
# Name: Lepidolite K(Li,Al)3(Si,Al)_4O_10(F,OH)_2
#
# 130
# Name: Microcline (Feldspar) (K,Na)AlSi_3O_8
#
# 131
# Name: Biotite K(Mg,Fe+2)3(Al,Fe+3)Si3O10(OH,F)2
#
# 132
# Name: Magnesiochromite MgCr_2O_4
#
# 133
# Name: Hematite alpha Fe_2O_3
#
# 134
# Name: Azurite Cu_3(CO_3)_2(OH)_2
#
# 135
# Name: Calcite CaCO_3
#
# 136
# Name: Anhydrite CaSO_4
#
# 137
# Name: Richterite Na2Ca(Mg,Fe+2)5Si8O22(OH)2
#
# 138
# Name: Saponite (Ca/2,Na)_0.33(Mg,Fe^2+)_3(Si,Al)_4O_10(OH)_2.4H_2O
#
# 139
# Name: Clinochlore (Chlorite) (Mg,Al)_6(Si,Al)_4O_10(OH)_8
#
# 140
# Name: Augite (Ca,Na)(Mg,Fe,Al,Ti)(Si,Al)2O6
#
# 141
# Name: Kernite Na_2B_4O_6(OH)_2.3H_2O
#
# 142
# Name: Hornblende Ca2(Fe+2,Mg)4Al(Si7Al)O22(OH,F)2
#
# 143
# Name: Halite NaCl
#
# 144
# Name: Anatase TiO_2
#
# 145
# Name: Labradorite (Feldspar) (NaSi,CaAl)AlSi_2O_8
#
# 146
# Name: Hornblende Ca2(Fe+2,Mg)4Al(Si7Al)O22(OH,F)2
#
# 147
# Name: Montebrasite LiAlPO_4(OH)
#
# 148
# Name: Stilbite NaCa_2Al_5Si_3O_36.14H_2O
#
# 149
# Name: Cryolite Na_3AlF_6
#
# 150
# Name: Meyerhofferite Ca2B6O6(OH)10 * H2O
#
# 151
# Name: Fluorite CaF_2
#
# 152
# Name: Labradorite (Na,Ca)Al(Al,Si)Si2O8
#
# 153
# Name: Cryolite Na_3AlF_6
#
# 154
# Name: Buddingtonite (Feldspar) (NH_4)AlSi_3O_8.0.5H_2O
#
# 155
# Name: Chalcopyrite CuFeS_2
#
# 156
# Name: Wollastonite CaSiO_3
#
# 157
# Name: Chalcocite Cu_2S
#
# 158
# Name: Natrojarosite NaFe_3^3+(SO_4)_2(OH)_6
#
# 159
# Name: Epidote Ca_2(Al,Fe^3+)_3O.SiO_4.Si_2O_7.OH
#
# 160
# Name: Carnallite KMgCl3 * 6H2O
#
# 161
# Name: Glauberite Na_2Ca(SO_4)_2
#
# 162
# Name: Sulphur S
#
# 163
# Name: Olivine (Fo51) (Fe+2,Mg)2SiO4
#
# 164
# Name: Zircon ZrSiO_4
#
# 165
# Name: Anhydrite CaSO_4
#
# 166
# Name: Orthoclase (Feldspar) (K,Na)AlSi_3O_8
#
# 167
# Name: Aragonite CaCO3
#
# 168
# Name: Dolomite CaMg(CO_3)_2
#
# 169
# Name: Dolomite CaMg(CO3)2
#
# 170
# Name: Sulphur S
#
# 171
# Name: Hemimorphite Zn_4Si_2O_7(OH)_2.H_2O
#
# 172
# Name: Hemimorphite Zn_4Si_2O_7(OH)_2.H_2O
#
# 173
# Name: Hematite alpha Fe_2O_3
#
# 174
# Name: Malachite Cu_2(CO_3)(OH)_2
#
# 175
# Name: Cordierite Mg_2Al_3(Si_5Al)O_18
#
# 176
# Name: Serpentine (Mg,Fe^2+,Ni)Si_2O_5(OH)_4
#
# 177
# Name: Bloedite Na2Mg(So4)2 * 3H2O
#
# 178
# Name: Sillimanite Al_2SiO_5
#
# 179
# Name: Ulexite NaCaB5O6(OH)6 * 5H2O
#
# 180
# Name: Magnetite Fe+2Fe2+3O4
#
# 181
# Name: Hematite alpha Fe_2O_3
#
# 182
# Name: Albite (Feldspar) (K,Na)AlSi_3O_8
#
# 183
# Name: Vesuvianite Ca_10(Mg,Fe^2+)_2Al_4(Si_2O_7)_2(SiO_4)_5(OH,F)_4
#
# 184
# Name: Apatite Ca_5(PO_4)_3F
#
# 185
# Name: Gypsum CaSO_4.2H_2O
#
# 186
# Name: Ulexite NaCaB_5O_6(OH)_6.5H_2O
#
# 187
# Name: Chalcopyrite CuFeS_2
#
# 188
# Name: Scheelite CaWO_4
#
# 189
# Name: Stibnite Sb_2S_3
#
# 190
# Name: Chalcocite Cu_2S
#
# 191
# Name: Muscovite KAl_2(Si_3Al)O_10(OH,F)_2
#
# 192
# Name: Grossular Garnet Ca_3Al_2(SiO_4)_3
#
# 193
# Name: Grossular Garnet Ca_3Al_2(SiO_4)_3
#
# 194
# Name: Johannsenite Ca(Mn,Fe^2+)(SiO_3)_2
#
# 195
# Name: Quartz SiO_2
#
# 196
# Name: Pyrrhotite Fe_1-xS
#
# 197
# Name: Talc Mg_3Si_4O_10(OH)_2
#
# 198
# Name: Rutile TiO_2
#
# 199
# Name: Aphthitalite (K,Na)_3Na(SO_4)_2
#
# 200
# Name: Glauberite Na_2Ca(SO_4)_2
#
# 201
# Name: Borax Na_2B_4O_5(OH)_4.8H_2O
#
# 202
# Name: Chlorite
#
# 203
# Name: Tincalconite Na_2B_4O_5(OH)_4.3H_2O
#
# 204
# Name: Trona Na_3(CO_3)(HCO_3).2H_2O
#
# 205
# Name: Chlorite
#
# 206
# Name: Lepidolite K(Li,Al)3(Si,Al)_4O_10(F,OH)_2
#
# 207
# Name: Enstatite Mg2Si2O6
#
# 208
# Name: Rivadavite Na6MgB24O40 * 22H2O
#
# 209
# Name: Topaz Al2SiO4(F,OH)2
#
# 210
# Name: Cookeite LiAl_4(Si_3Al)O_10(OH)_8
#
# 211
# Name: Columbite Fe^2+Nb_2O_6
#
# 212
# Name: Dickite Al_2Si_2O_5(OH)_4
#
# 213
# Name: Columbite Fe^2+Nb_2O_6
#
# 214
# Name: Beryl Be3Al2Si6O18
#
# 215
# Name: Ulexite NaCaB_5O_6(OH)_6.5H_2O
#
# 216
# Name: Calcite CaCO_3
#
# 217
# Name: Amblygonite (Li,Na)Al(PO_4)(F,OH)
#
# 218
# Name: Andesine (Feldspar) (NaSi,CaAl)AlSi_2O_8
#
# 219
# Name: Dolomite CaMg(CO_3)_2
#
# 220
# Name: Colemanite Ca_2B_6O_11.5H_2O
#
# 221
# Name: Sulphur S
#
# 222
# Name: Antlerite Cu_3(SO_4)(OH)_4
#
# 223
# Name: Rhodochrosite MnCO_3
#
# 224
# Name: Beryl Be_3Al_2Si_6O_18
#
# 225
# Name: Vermiculite (Mg,Fe^2+,Al)_3(Al,Si)_4O_10(OH)_2.4H_2O
#
# 226
# Name: Pyrolusite MnO_2
#
# 227
# Name: Quartz SiO_2
#
# 228
# Name: Bustamite (Mn,Ca)3Si3O9
# 229
# Name: Ferroaxinite Ca_2Fe^2+Al_2BSi_4O_15(OH)
#
# 230
# Name: Sphalerite (Zn,Fe)S
#
# 231
# Name: Johannsenite Ca(Mn,Fe^2+)(SiO_3)_2
#
# 232
# Name: Realgar AsS
#
# 233
# Name: Olivine (Fo92) (Fe+2,Mg)2SiO4
#
# 234
# Name: Tremolite Ca2(Mg, Fe+2)5Si8O22(OH)2
#
# 235
# Name: Chlorite
#
# 236
# Name: Tincalconite Na_2B_4O_5(OH)_4.3H_2O
#
# 237
# Name: Epidote Ca_2(Al,Fe^3+)_3O.SiO_4.Si_2O_7.OH
#
# 238
# Name: Alunite KAl_3(SO_4)_2(OH)_6
#
# 239
# Name: Illite (K,H3O)(Al,Mg,Fe)2(Si,Al)4O10[(OH)2,H2O]
#
# 240
# Name: Calcite CaCO_3
#
# 241
# Name: Apatite Ca_5(PO_4)_3F
#
# 242
# Name: Kernite Na_2B_4O_6(OH)_2.3H_2O
#
# 243
# Name: Borax Na_2B_4O_5(OH)_4.8H_2O
#
# 244
# Name: Gypsum (selenite) CaSO4.2H2O
#
# 245
# Name: Corrensite (Mg,Fe)_9(Si,Al)_8O_20(OH)_10._xH_2O
#
# 246
# Name: Spodumene LiAlS_2O_6
#
# 247
# Name: Glauconite (K,Na)(Fe^3+,Al,Mg)_2(Si,Al)_4O_10(OH)_2
#
# 248
# Name: Celestite SrSO_4
#
# 249
# Name: Prehnite Ca2Al2Si3O10(OH)2
#
# 250
# Name: Alunite (ammonioalunite) NH4Al3(SO4)2(OH)6
#
# 251
# Name: Vesuvianite Ca10Mg2Al4(SiO4)5(Si2O7)2(OH)4
#
# 252
# Name: Magnesiochromite MgCr_2O_4
#
# 253
# Name: Scorodite Fe^3+AsO_4.2H_2O
#
# 254
# Name: Nepheline (Na,K)AlSiO_4
#
# 255
# Name: Realgar AsS
#
# 256
# Name: Howlite Ca_2B_5SiO_9(OH)_5
#
# 257
# Name: Dolomite CaMg(CO_3)_2
#
# 258
# Name: Titanite (Sphene) CaTiSiO_5
#
# 259
# Name: Pyrophyllite Al_2Si_4O_10(OH)_2
#
# 260
# Name: Tschermigite (NH_4)Al(SO_4)_2.12H_2O
#
# 261
# Name: Molybdenite MoS_2
#
# 262
# Name: Scorodite Fe^3+AsO_4.2H_2O
#
# 263
# Name: AtacamiteCu_2Cl(OH)_3
#
# 264
# Name: Cerussite, PbCO3
#
# 265
# Name: Bornite Cu_5FeS_4
#
# 266
# Name: Olivine (Fo92) (Fe+2,Mg)2SiO4
#
# 267
# Name: Howlite Ca_2B_5SiO_9(OH)_5
#
# 268
# Name: Calcite CaCO_3
#
# 269
# Name: Beryl Be3Al2Si6O18
#
# 270
# Name: Stilbite NaCa_2Al_5Si_3O_36.14H_2O
#
# 271
# Name: Prehnite Ca_2Al_2Si_3O_10(OH)_2
#
# 272
# Name: Anorthite (Feldspar) (NaSi,CaAl)AlSi_2O_8
#
# 273
# Name: Corundum Al_2O_3
#
# 274
# Name: Scheelite CaWO_4
#
# 275
# Name: Titanite (Sphene) CaTiSiO_5
#
# 276
# Name: Diopside CaMg(SiO_3)_2
#
# 277
# Name: Cerussite PbCO_3
#
# 278
# Name: Pyrope Mg3Al2(SiO4)3
#
# 279
# Name: Magnetite Fe+2Fe2+3O4
#
# 280
# Name: Andalusite Al2SiO5
#
# 281
# Name: Jarosite KFe_3^3+(SO_4)_2(OH)_6
#
# 282
# Name: Tincalconite Na_2B_4O_5(OH)_4.3H_2O
#
# 283
# Name: Graphite C
#
# 284
# Name: Labradorite (Feldspar) (NaSi,CaAl)AlSi_2O_8
#
# 285
# Name: Orthoclase (Feldspar) (K,Na)AlSi_3O_8
#
# 286
# Name: Molybdenite MoS_2
#
# 287
# Name: Tschermigite (NH_4)Al(SO_4)_2.12H_2O
#
# 288
# Name: Pyrolusite MnO_2
#
# 289
# Name: Sodalite Na_8Al_6Si_6O_24Cl_2
#
# 290
# Name: Quartz SiO_2
#
# 291
# Name: Almandine Garnet Fe_3Al_2(SiO_4)_3
#
# 292
# Name: Rhodonite (Mn,Ca)SiO_3
#
# 293
# Name: Glauconite (K,Na)(Fe^3+,Al,Mg)_2(Si,Al)_4O_10(OH)_2
#
# 294
# Name: Mimetite Pb_5(AsO_4)_3Cl
#
# 295
# Name: Acmite NaFe+3Si2O6
#
# 296
# Name: Gahnite ZnAl_2O_4
#
# 297
# Name: Kaolinite Al2Si2O5(OH)4
#
# 298
# Name: Kernite Na_2B_4O_6(OH)_2.3H_2O
#
# 299
# Name: Borax Na_2B_4O_5(OH)_4.8H_2O
#
# 300
# Name: Cryolite Na_3AlF_6
#
# 301
# Name: Lepidolite K(Li,Al)3(Si,Al)_4O_10(F,OH)_2
#
# 302
# Name: Pyrite FeS_2
#
# 303
# Name: Pectolite NaCa2Si308(OH)
#
# 304
# Name: Enstatite Mg_2(SiO_3)_2
#
# 305
# Name: Apatite Ca_5(PO_4)_3F
#
# 306
# Name: Tremolite Ca_2(Mg,Fe^2+)_5Si_8O_22(OH)_2
#
# 307
# Name: Natrojarosite NaFe_3^3+(SO_4)_2(OH)_6
#
# 308
# Name: Prehnite Ca_2Al_2Si_3O_10(OH)_2
#
# 309
# Name: Actinolite Ca_2(Mg,Fe^2+)_5Si_8O_22(OH)_2
#
# 310
# Name: Realgar AsS
#
# 311
# Name: Datolite CaBSiO4(OH)
#
# 312
# Name: Dolomite CaMg(CO_3)_2
#
# 313
# Name: Colemanite Ca_2B_6O_11.5H_2O
#
# 314
# Name: Magnetite Fe+2Fe2+3O4
#
# 315
# Name: Pyrope Mg3Al2(SiO4)3
#
# 316
# Name: Vermiculite (Mg,Fe^2+,Al)_3(Al,Si)_4O_10(OH)_2.4H_2O
#
# 317
# Name: Quartz SiO_2
#
# 318
# Name: Quartz SiO_2
#
# 319
# Name: Albite (Feldspar) (K,Na)AlSi_3O_8
#
# 320
# Name: Molybdenite MoS_2
#
# 321
# Name: Olivine (Fo92) (Fe+2,Mg)2SiO4
#
# 322
# Name: Acmite NaFe+3Si2O6
#
# 323
# Name: Chlorite
#
# 324
# Name: Malachite Cu_2(CO_3)(OH)_2
#
# 325
# Name: Labradorite (Feldspar) (NaSi,CaAl)AlSi_2O_8
#
# 326
# Name: Cordierite Mg_2Al_3(Si_5Al)O_18
#
# 327
# Name: Sillimanite Al_2SiO_5
#
# 328
# Name: Cordierite Mg_2Al_3(Si_5Al)O_18
#
# 329
# Name: Antlerite Cu_3(SO_4)(OH)_4
#
# 330
# Name: Pectolite NaCa2Si308(OH)
#
# 331
# Name: Anglesite PbSO_4
#
# 332
# Name: Chalcopyrite CuFeS_2
#
# 333
# Name: Oligoclase (Feldspar) (NaSi,CaAl)AlSi_2O_8
#
# 334
# Name: Enstatite Mg_2(SiO_3)_2
#
# 335
# Name: Ulexite NaCaB_5O_6(OH)_6.5H_2O
#
# 336
# Name: Nontronite Na_0.33Fe_2^3+(Si,Al)_4O_10(OH)_2.H_2O
#
# 337
# Name: Chabazite CaAl2Si4O12.6H2O
#
# 338
# Name: Bytownite (Feldspar) (NaSi,CaAl)AlSi_2O_8
#
# 339
# Name: Stilbite NaCa_2Al_5Si_3O_36.14H_2O
#
# 340
# Name: Grossular Garnet Ca_3Al_2(SiO_4)_3
#
# 341
# Name: Enstatite Mg_2(SiO_3)_2
#
# 342
# Name: Quartz SiO_2
#
# 343
# Name: Grossular Garnet Ca_3Al_2(SiO_4)_3
#
# 344
# Name: Johannsenite Ca(Mn,Fe^2+)(SiO_3)_2
#
# 345
# Name: Dolomite CaMg(CO3)2
#
# 346
# Name: Biotite K(Mg,Fe^2+)_3(Al,Fe^3+)Si_3O_10(OH,F)_2
#
# 347
# Name: Glauberite Na_2Ca(SO_4)_2
#
# 348
# Name: Tremolite Ca2(Mg, Fe+2)5Si8O22(OH)2
#
# 349
# Name: Calcite CaCO_3
#
# 350
# Name: Nontronite Na_0.33Fe_2^3+(Si,Al)_4O_10(OH)_2.H_2O
#
# 351
# Name: Anthophyllite (Mg,Fe^2+)_7Si_8O_22(OH)_2
#
# 352
# Name: Calcite CaCO_3
#
# 353
# Name: Quartz SiO_2
#
# 354
# Name: Anhydrite CaSO_4
#
# 355
# Name: Scheelite CaWO_4
#
# 356
# Name: Epidote Ca_2(Al,Fe^3+)_3O.SiO_4.Si_2O_7.OH
#
# 357
# Name: Hematite a-Fe2O3
#
# 358
# Name: Witherite BaCO_3
#
# 359
# Name: Molybdenite MoS_2
#
# 360
# Name: Columbite Fe^2+Nb_2O_6
#
# 361
# Name: Hydroxyapophyllite KCa_4Si_8O_20(OH,F).8H_2O
#
# 362
# Name: Chlorite
#
# 363
# Name: Hemimorphite Zn_4Si_2O_7(OH)_2.H_2O
#
# 364
# Name: Richterite Na2Ca(Mg,Fe+2)5Si8O22(OH)2
#
# 365
# Name: Mordenite (Ca,Na2,K2)Al2Si10O24.7H2O
#
# 366
# Name: Serpentine (Mg,Fe^2+,Ni)Si_2O_5(OH)_4
#
# 367
# Name: Richterite Na2Ca(Mg,Fe+2)5Si8O22(OH)2
#
# 368
# Name: Quartz SiO2
#
# 369
# Name: Grossular Garnet Ca_3Al_2(SiO_4)_3
#
# 370
# Name: Vermiculite (Mg,Fe^2+,Al)_3(Al,Si)_4O_10(OH)_2.4H_2O
#
# 371
# Name: Montmorillonite (Na,Ca)0.33(Al,Mg)2Si4O10(OH)2.nH2O
#
# 372
# Name: Spodumene LiAlS_2O_6
#
# 373
# Name: Azurite Cu_3(CO_3)_2(OH)_2
#
# 374
# Name: Clinochlore (Chlorite) (Mg,Al)_6(Si,Al)_4O_10(OH)_8
#
# 375
# Name: Calcite CaCO_3
#
# 376
# Name: Calcite CaCO_3
#
# 377
# Name: Cookeite LiAl_4(Si_3Al)O_10(OH)_8
#
# 378
# Name: Cummingtonite (Mg,Fe^2+)_7Si_8O_22(OH)_2
#
# 379
# Name: Quartz SiO_2
#
# 380
# Name: Dolomite CaMg(CO_3)_2
#
# 381
# Name: Graphite C
#
# 382
# Name: Nepheline (Na,K)AlSiO4
#
# 383
# Name: Sepiolite Mg_4Si_6O_15(OH)_2.6H_2O
#
# 384
# Name: Andradite Ca3Fe2+3 (SiO4)3
#
# 385
# Name: Natrolite Na_2Al_2Si_3O_10.2H_2O
#
# 386
# Name: Grossular Ca3Al2(Si04)3
#
# 387
# Name: Trona Na_3(CO_3)(HCO_3).2H_2O
#
# 388
# Name: Tremolite Ca_2(Mg,Fe^2+)_5Si_8O_22(OH)_2
#
# 389
# Name: Azurite Cu_3(CO_3)_2(OH)_2
#
# 390
# Name: Labradorite (Feldspar) (NaSi,CaAl)AlSi_2O_8
#
# 391
# Name: Magnetite Fe^2+Fe_2^3+O_4
#
# 392
# Name: Rhodonite (Mn,Ca)SiO_3
#
# 393
# Name: Gypsum CaSO_4.2H_2O
#
# 394
# Name: Monticellite CaMgSiO4
#
# 395
# Name: Datolite CaBSiO4(OH)
#
# 396
# Name: Mimetite Pb_5(AsO_4)_3Cl
#
# 397
# Name: Rhodonite (Mn+2,Fe+2,Mg,Ca)SiO3
#
# 398
# Name: Calcite CaCO_3
#
# 399
# Name: Corundum Al_2O_3
#
# 400
# Name: Erionite (K2,Ca,Na2)2Al4Si14O36.15H2O
#
# 401
# Name: Diopside CaMg(SiO_3)_2
#
# 402
# Name: Cordierite Mg2Al4Si5O18
#
# 403
# Name: Montmorillonite (Na,Ca)_0.33(Al,Mg)_2Si_4O_10(OH)_2.H_2O
#
# 404
# Name: Calcite CaCO3
#
# 405
# Name: Calcite CaCO_3
#
# 406
# Name: Glauberite Na_2Ca(SO_4)_2
#
# 407
# Name: Clinochlore (Chlorite) (Mg,Al)_6(Si,Al)_4O_10(OH)_8
#
# 408
# Name: Aphthitalite (K,Na)_3Na(SO_4)_2
#
# 409
# Name: Ilmenite Fe+2TiO3
#
# 410
# Name: Cassiterite SnO_2
#
# 411
# Name: Beryl Be_3Al_2Si_6O_18
#
# 412
# Name: Tremolite Ca2(Mg, Fe+2)5Si8O22(OH)2
#
# 413
# Name: Magnesite MgCO_3
#
# 414
# Name: Amblygonite (Li,Na)Al(PO_4)(F,OH)
#
# 415
# Name: Zincite (Zn,Mn)O
#
# 416
# Name: Calcite CaCO3
#
# 417
# Name: Hydroxyapophyllite KCa_4Si_8O_20(OH,F).8H_2O
#
# 418
# Name: Wollastonite CaSiO_3
#
# 419
# Name: Kyanite Al2SiO5
#
# 420
# Name: Apatite Ca_5(PO_4)_3F
#
# 421
# Name: Trona Na_3(CO_3)(HCO_3).2H_2O
#
# 422
# Name: Calcite CaCO3
#
# 423
# Name: Plumbojarosite PbFe_3^3+(SO_4)_4(OH)_12
#
# 424
# Name: Actinolite Ca_2(Mg,Fe^2+)_5Si_8O_22(OH)_2
#
# 425
# Name: Buddingtonite (Feldspar) (NH_4)AlSi_3O_8.0.5H_2O
#
# 426
# Name: Tremolite Ca_2(Mg,Fe^2+)_5Si_8O_22(OH)_2
#
# 427
# Name: Magnesite MgCO_3
#
# 428
# Name: Barite, BaSO4
#
# 429
# Name: Nontronite Na_0.33Fe_2^3+(Si,Al)_4O_10(OH)_2.H_2O
#
# 430
# Name: Brucite Mg(OH)_2
#
# 431
# Name: Alunite (sodium alunite) NaAl3(SO4)2(OH)6
#
# 432
# Name: Cordierite Mg2Al4Si5O18
#
# 433
# Name: Phlogopite KMg3Si3Al010(F,OH)2
#
# 434
# Name: Kaolinite Al2Si2O5(OH)4
#
# 435
# Name: Ulexite NaCaB_5O_6(OH)_6.5H_2O
#
# 436
# Name: Biotite K(Mg,Fe^2+)_3(Al,Fe^3+)Si_3O_10(OH,F)_2
#
# 437
# Name: Calcite CaCO_3
#
# 438
# Name: Riebeckite Na_2(Fe^2+,Mg)_3,Fe_2^3+Si_8O_22(OH)_2
#
# 439
# Name: Triphylite Li(Mn,Fe)PO_4
#
# 440
# Name: Strontianite SrCO_3
#
# 441
# Name: Mimetite Pb_5(AsO_4)_3Cl
#
# 442
# Name: Anhydrite CaSO_4
#
# 443
# Name: Celestite SrSO_4
#
# 444
# Name: Illite/smectite (K,H3O)(Al,Mg,Fe)2(Si,Al)4 O10 [(OH)2,H2O]
#
# 445
# Name: Andalusite Al2SiO5
#
# 446
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-80-78c8fb2e044f> in <module>
#       8     fi = open(row.Spectrum, "r")
#       9 #     print(fi.readline().strip().split()[1])
# ---> 10     print(fi.readline())
#
# ~/Desktop/Programs/Virtual Environments/spectra-ml-env/lib/python3.7/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd1 in position 587: invalid continuation byte

# %%
# plt.plot(data["Reflectance"])
plt.plot(data.iloc[:, 1])
plt.title('Reflectance vs Wavelength')
plt.ylabel('Reflectance')
plt.xlabel('Wavelength')
# plt.legend(['Reflectance'], loc='upper right')
# Out:
# Text(0.5, 0, 'Wavelength')
